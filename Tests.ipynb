# %%
import nltk
nltk.download('punkt', './nltk_data')
nltk.data.path.append('./nltk_data/')
sent_detector = nltk.data.load('tokenizers/punkt/english.pickle')
# Out:
# [nltk_data] Downloading package punkt to ./nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
from bs4 import BeautifulSoup
from unipath import Path
import re

# %%
p = Path('./riddlescrape/data/')

# %%
paths = []
for html_path in p.walk(filter=lambda p: p.isfile() and re.match(r".*html", p.name)):
    paths.append(html_path)

paths
# Out:
# [Path(u'./riddlescrape/data/1.html'),
#  Path(u'./riddlescrape/data/10.html'),
#  Path(u'./riddlescrape/data/11.html'),
#  Path(u'./riddlescrape/data/12.html'),
#  Path(u'./riddlescrape/data/13.html'),
#  Path(u'./riddlescrape/data/14.html'),
#  Path(u'./riddlescrape/data/15.html'),
#  Path(u'./riddlescrape/data/16.html'),
#  Path(u'./riddlescrape/data/17.html'),
#  Path(u'./riddlescrape/data/18.html'),
#  Path(u'./riddlescrape/data/19.html'),
#  Path(u'./riddlescrape/data/2.html'),
#  Path(u'./riddlescrape/data/20.html'),
#  Path(u'./riddlescrape/data/21.html'),
#  Path(u'./riddlescrape/data/22.html'),
#  Path(u'./riddlescrape/data/23.html'),
#  Path(u'./riddlescrape/data/24.html'),
#  Path(u'./riddlescrape/data/25.html'),
#  Path(u'./riddlescrape/data/26.html'),
#  Path(u'./riddlescrape/data/27.html'),
#  Path(u'./riddlescrape/data/28.html'),
#  Path(u'./riddlescrape/data/29.html'),
#  Path(u'./riddlescrape/data/3.html'),
#  Path(u'./riddlescrape/data/30.html'),
#  Path(u'./riddlescrape/data/31.html'),
#  Path(u'./riddlescrape/data/32.html'),
#  Path(u'./riddlescrape/data/33.html'),
#  Path(u'./riddlescrape/data/34.html'),
#  Path(u'./riddlescrape/data/35.html'),
#  Path(u'./riddlescrape/data/36.html'),
#  Path(u'./riddlescrape/data/37.html'),
#  Path(u'./riddlescrape/data/38.html'),
#  Path(u'./riddlescrape/data/39.html'),
#  Path(u'./riddlescrape/data/4.html'),
#  Path(u'./riddlescrape/data/40.html'),
#  Path(u'./riddlescrape/data/41.html'),
#  Path(u'./riddlescrape/data/42.html'),
#  Path(u'./riddlescrape/data/43.html'),
#  Path(u'./riddlescrape/data/44.html'),
#  Path(u'./riddlescrape/data/45.html'),
#  Path(u'./riddlescrape/data/46.html'),
#  Path(u'./riddlescrape/data/47.html'),
#  Path(u'./riddlescrape/data/48.html'),
#  Path(u'./riddlescrape/data/49.html'),
#  Path(u'./riddlescrape/data/5.html'),
#  Path(u'./riddlescrape/data/50.html'),
#  Path(u'./riddlescrape/data/51.html'),
#  Path(u'./riddlescrape/data/52.html'),
#  Path(u'./riddlescrape/data/53.html'),
#  Path(u'./riddlescrape/data/54.html'),
#  Path(u'./riddlescrape/data/55.html'),
#  Path(u'./riddlescrape/data/56.html'),
#  Path(u'./riddlescrape/data/57.html'),
#  Path(u'./riddlescrape/data/58.html'),
#  Path(u'./riddlescrape/data/59.html'),
#  Path(u'./riddlescrape/data/6.html'),
#  Path(u'./riddlescrape/data/60.html'),
#  Path(u'./riddlescrape/data/61.html'),
#  Path(u'./riddlescrape/data/62.html'),
#  Path(u'./riddlescrape/data/63.html'),
#  Path(u'./riddlescrape/data/64.html'),
#  Path(u'./riddlescrape/data/65.html'),
#  Path(u'./riddlescrape/data/66.html'),
#  Path(u'./riddlescrape/data/67.html'),
#  Path(u'./riddlescrape/data/68.html'),
#  Path(u'./riddlescrape/data/69.html'),
#  Path(u'./riddlescrape/data/7.html'),
#  Path(u'./riddlescrape/data/70.html'),
#  Path(u'./riddlescrape/data/71.html'),
#  Path(u'./riddlescrape/data/72.html'),
#  Path(u'./riddlescrape/data/73.html'),
#  Path(u'./riddlescrape/data/74.html'),
#  Path(u'./riddlescrape/data/75.html'),
#  Path(u'./riddlescrape/data/76.html'),
#  Path(u'./riddlescrape/data/77.html'),
#  Path(u'./riddlescrape/data/78.html'),
#  Path(u'./riddlescrape/data/79.html'),
#  Path(u'./riddlescrape/data/8.html'),
#  Path(u'./riddlescrape/data/80.html'),
#  Path(u'./riddlescrape/data/81.html'),
#  Path(u'./riddlescrape/data/82.html'),
#  Path(u'./riddlescrape/data/83.html'),
#  Path(u'./riddlescrape/data/84.html'),
#  Path(u'./riddlescrape/data/85.html'),
#  Path(u'./riddlescrape/data/86.html'),
#  Path(u'./riddlescrape/data/87.html'),
#  Path(u'./riddlescrape/data/88.html'),
#  Path(u'./riddlescrape/data/89.html'),
#  Path(u'./riddlescrape/data/9.html'),
#  Path(u'./riddlescrape/data/90.html'),
#  Path(u'./riddlescrape/data/91.html'),
#  Path(u'./riddlescrape/data/Anglo-Saxon_Riddles_of_the_Exeter_Book.html'),
#  Path(u'./riddlescrape/data/Bibliographical_Note.html'),
#  Path(u'./riddlescrape/data/I._Natural_Phenomena.html'),
#  Path(u'./riddlescrape/data/II._Chiefly_Christian.html'),
#  Path(u'./riddlescrape/data/III._Birds.html'),
#  Path(u'./riddlescrape/data/IV._Other_Animals.html'),
#  Path(u'./riddlescrape/data/IX._Horn.html'),
#  Path(u'./riddlescrape/data/Index_of_Solutions.html'),
#  Path(u'./riddlescrape/data/Introduction.html'),
#  Path(u'./riddlescrape/data/Latin.html'),
#  Path(u'./riddlescrape/data/Numbering_of_the_Translations_and_the_Krapp%E2%80%93Dobbie_Edition.html'),
#  Path(u'./riddlescrape/data/Quondam_First_Riddle.html'),
#  Path(u'./riddlescrape/data/V._Domestic_Subjects.html'),
#  Path(u'./riddlescrape/data/VI._Writing.html'),
#  Path(u'./riddlescrape/data/VII._Music.html'),
#  Path(u'./riddlescrape/data/VIII._Weapons,_Fighting.html'),
#  Path(u'./riddlescrape/data/X._Miscellaneous.html'),
#  Path(u'./riddlescrape/data/XI._Runes.html'),
#  Path(u"./riddlescrape/data/XII._The_'Obscene'_Riddles.html"),
#  Path(u'./riddlescrape/data/XIII._Fragments.html')]

# %%
prose = []
english_riddles = []
old_english_riddles = []
for path in paths:
    soup = BeautifulSoup(path.read_file())
    prose = prose + [tag.text for tag in soup.select('div.prose p')]
    for row in soup.select("table tr"):
        row_tds = row.findAll('td', {'align': 'left'})
        if len(row_tds) > 1:
            english_riddles.append(row_tds[0].text.strip())
            old_english_riddles = old_english_riddles + [tag.text.strip() for tag in row_tds[1:]]
print len(prose)
print len(english_riddles)
print len(old_english_riddles)
# Out:
# 337
# 98
# 100

# %%
for i, riddle in enumerate(english_riddles):
    if len(riddle) > 0 and len(riddle) < 140:
        print i, riddle
# Out:
# 23 I saw a woman     sitting alone.
# 54 I am an atheling’s     possession and delight
# 71 I saw the wight     going on its way.
# It was splendidly,     wonderfully arrayed.
# The wonder was on the wave;     water became bone.
# 75 I saw a swift one     going along the path

# %%
riddle_sentences = []
for riddle in english_riddles:
    sentences = sent_detector.tokenize(riddle.strip())
    riddle_sentences = riddle_sentences + filter(lambda x: len(x) > 15, sentences)
len(riddle_sentences)
# Out:
# 566

# %%
for i, sentence in enumerate(riddle_sentences):
    print "%s :: %s (%s)" % (i, sentence, len(sentence))
# Out:
# 0 :: What good man is     so learned and so clever
# that he can say who drives me     forth on my way? (96)
# 1 :: When I rise up strong     at times furious,
# I thunder mightily     and again with havoc
# I sweep over the land,     burn the great hall,
# ravage the buildings. (157)
# 2 :: Smoke mounts on high
# dark over the rooftops. (44)
# 3 :: Clamor is everywhere,
# sudden death among men. (45)
# 4 :: When I shake the forest,
# the trees proud in their fruit,     I fell the boles. (78)
# 5 :: With my roof of water,     by the powers above
# I am driven far and wide     on my avenging path. (96)
# 6 :: I bear on my back     what once covered the forms
# of the earth-dwellers,     their body and soul
# together in the waters. (120)
# 7 :: Say what covers me
# or what I am called     who bear this burden. (64)
# 8 :: I know a noble guest,     dear to princes,
# whom grim hunger     cannot harm,
# nor hot thirst,     nor age nor illness. (117)
# 9 :: If kindly the servant     always tend him,
# he who must go     along on the journey;
# safe and certain     they will find at home
# food and joy     and countless kin;
# but sorrow if the servant     obeys his lord badly,
# his master on their journey;     nor will brother fear brother
# when unharmed they leave quickly     the bosom of their kin,
# mother and sister. (358)
# 10 :: Let whoever will
# with fitting words     name the guest or the servant
# I speak of here. (86)
# 11 :: Eternal is the Creator     who controls this earth now
# on its foundations …     [and] holds the world. (102)
# 12 :: Strong is the Ruler     and King by right,
# mighty over all. (59)
# 13 :: The earth and the heavens
# He holds and wields     as He encircles them about. (77)
# 14 :: Me he wondrously     made at the beginning
# when at the first     he established this universe. (94)
# 15 :: He bade me to live     long unsleeping
# that I slumber not     forever after. (76)
# 16 :: And me suddenly     sleep overcomes;
# both my eyes     are quickly closed. (73)
# 17 :: All this world     the mighty Lord
# moves with mastery     in all its parts;
# so that I at the world     of the mighty ruler
# all this universe     encircle about. (160)
# 18 :: I am so timid     that a fleeting phantom
# terribly can     fill me with fright;
# and I am everywhere     bolder than a boar
# when swollen with fury     it stands at bay. (167)
# 19 :: No banner-bearer     can overcome me
# throughout the world     save God alone
# who holds and rules     this high heaven. (118)
# 20 :: My fragrance is stronger     . (30)
# 21 :: than any incense     or any rose
# in the field of earth     . (60)
# 22 :: beautifully blooms;     I am stronger than that. (48)
# 23 :: Although the lily     is precious to men,
# and bright of blossom     I am better than it;
# thus the odor of nard     I (quite) overcome
# with my very sweetness     ever and everywhere. (181)
# 24 :: And I am fouler     than this black fen
# that here evilly     smells of filth. (77)
# 25 :: And I govern     under heaven’s expanse
# as the beloved Father     taught me at the start,
# that I must rule     with right justice
# over thick and thin,     and everywhere hold
# the form and feature     of every thing. (215)
# 26 :: I am brighter than heaven;     the high King bids me
# to hold and cherish     his secret treasures. (98)
# 27 :: I scan all things also     under the earth,
# the dirty dens     of evil spirits. (79)
# 28 :: I am very much older     than this universe
# or this middle-world     could ever be. (83)
# 29 :: I was yesterday born,     a child begotten
# to the glory of man,     from my mother’s womb. (90)
# 30 :: Fairer I am     than ornaments of gold,
# although they be covered     with delicate work. (88)
# 31 :: I am filthier too     than this foul wood
# or this seaweed     that lies cast up here. (85)
# 32 :: I am wider than the world     any and everywhere
# and extend farther     than this green meadow. (95)
# 33 :: A hand can seize me     and three fingers
# can easily embrace me     all round about. (84)
# 34 :: I am harder and colder     than the hard frost;
# the grim rime     when it comes on the ground. (94)
# 35 :: [I am] hotter than Vulcan’s     up-ascending
# fire and brightly     shining flame. (81)
# 36 :: I am on the palate     of men sweeter
# than the honeycomb     when filled with honey. (84)
# 37 :: Just so am I bitterer     than wormwood is
# that darkly stands     here in the forest. (85)
# 38 :: Feed I can     even more mightily
# and eat just as much     as an old giant,
# and I always can live     a happy life
# though I see no food     my whole life long. (159)
# 39 :: I can fly more boldly     than the pernex[2] can
# or eagle or hawk     ever could. (81)
# 40 :: There is no Zephyrus,     that rapid wind,
# that can anywhere     so boldly move. (80)
# 41 :: The snail is swifter than I,     the earthworm faster,
# the swamp frog     more active in movement
# and the offspring of dung     is quicker in stirring,
# which we call “beetle,”     when we give it a name. (203)
# 42 :: I am heavier far     than the gray stone
# or a lump of lead     which is not small. (82)
# 43 :: I am much lighter     than this little bug
# which walks on the water     with dry feet;
# than the flint I am harder     which drives this fire
# from this strong,     this hard, steel. (180)
# 44 :: I am softer far     than the downy feather
# that here in the wind     flutters on the air. (89)
# 45 :: I am everywhere     broader than all the earth
# and farther extend     than this green meadow. (93)
# 46 :: [3]
# I encircle …     all round about
# wondrously woven     with wonderful skill. (79)
# 47 :: Under me there is     no other
# more powerful wight     among living things. (75)
# 48 :: I am above     the creatures all
# which our Lord     did create
# who can me alone     by His eternal power
# restrain by force     from exceeding my bounds. (152)
# 49 :: I am greater and stronger     than the large whale
# which looks on the bottom     of the sea-deeps
# with dim vision;     I am mightier than he
# even as I am less     in my own strength
# than the handworm which     the sons of men
# in skilful manner     dig out with a knife. (269)
# 50 :: I have on my head     no white locks,
# cunningly curled,     but I am quite bald;
# nor could I enjoy     eyelids or eyebrows. (123)
# 51 :: But me the Creator     deprived of them all. (44)
# 52 :: Now wondrously     grow on my head
# so that they may     shine on my shoulders,
# full wondrously,     curly locks. (112)
# 53 :: I am bigger and fatter     than the masty swine,
# the grunting boar     in the beech forest
# that dark and rooting     happy lives,
# so that he …     . (148)
# 54 :: I am greater     than all this world is,
# less than the handworm,     brighter than the moon,
# swifter than the sun. (114)
# 55 :: All seas and waters
# are in my embraces,     and the bosom of earth
# and the green fields. (88)
# 56 :: I reach to the ground,
# I descend below hell,     I rise above the heavens,
# the land of glory. (93)
# 57 :: I extend far over
# the home of angels. (37)
# 58 :: I fill the earth,
# the whole wide world     and the ocean currents,
# all by myself. (81)
# 59 :: Say what my name is. (20)
# 60 :: I saw in the hall     where heroes drank
# a thing of four kinds     borne in thither. (84)
# 61 :: It was of splendid wood,     and twisted gold,
# skilfully wound,     and part of it silver;
# and the sign of the road     of Him who raised us
# step by step     up to heaven
# before he stormed     the castle of Hell’s people. (221)
# 62 :: I can readily report     on the excellence of the wood:
# there was maple and oak     and tough yew
# and the dark holly. (117)
# 63 :: They are all together
# a help to good men. (41)
# 64 :: One name they have:
# Wolf-head Tree,     that often afforded
# a weapon for its lord,     a treasure in the hall,
# a gold-hilted sword. (131)
# 65 :: Now show me the answer
# of this my song,     whoever may presume
# to say in words     how the wood is called. (107)
# 66 :: I am an active flame;     I sport with the wind,
# enwound with wonder,     enwrapped by the storm,
# eager on my way,     troubled by fire,
# a blooming grove,     a burning flame. (175)
# 67 :: Friends often pass me     from hand to hand
# so that men and women     proudly kiss me. (86)
# 68 :: When I rise up     they bow down to me,
# many joyfully,     where I shall add
# to the oncoming     of blessedness to men. (119)
# 69 :: I have heard of a ring     bright without tongue
# intercede for heroes. (70)
# 70 :: Well it spoke
# with strong words     though not loud. (52)
# 71 :: This treasure for men     silently said:
# “Heal me     helper of souls.”
# May men understand     the magic meaning
# of the speech of the red gold. (143)
# 72 :: May the wise entrust
# their salvation to God,     as the ring said. (66)
# 73 :: I saw in the hall     a golden ring
# which men beheld     with happy hearts,
# with wise minds. (92)
# 74 :: Peace and salvation
# has God offered     to every guest
# who turns the ring. (74)
# 75 :: A word then it spoke,
# the ring to the gathering. (48)
# 76 :: It named the Saviour
# of righteous men. (38)
# 77 :: Dumb it brought
# clearly to their minds     the Lord’s name
# and to the sight of their eyes     if one could grasp
# the true meaning     of the noble gold. (152)
# 78 :: The wounded Lord,     do as the wounds
# of the ring had said. (60)
# 79 :: Nor can to the prayer     . (27)
# 80 :: the soul of any man     unfulfilled
# seek the princely city,     the castle of heaven. (85)
# 81 :: Explain how the wounds     of this splendid ring
# spoke to mortals     when there in the hall
# it was turned and revolved     in the hands of the proud. (150)
# 82 :: Christ, the commander,     the true lord of victories,
# ordained me for conflict. (80)
# 83 :: I burn the living,
# unnumbered mortals,     over all the earth. (62)
# 84 :: I afflict them with pain,     yet never I touch them,
# whenever my lord     bids me to battle. (93)
# 85 :: Sometimes I gladden     the minds of many;
# sometimes I comfort     those I make war on,
# even from afar. (103)
# 86 :: They feel it, nonetheless,
# the hurt and the healing,     when now and again,
# over deep tribulation,     I better their fortunes. (128)
# 87 :: My garment is darkish. (22)
# 88 :: Bright decorations,
# red and radiant,     I have on my raiment. (62)
# 89 :: I mislead the stupid     and stimulate the foolish
# toward unwise ways. (70)
# 90 :: Others I restrain
# from profitable paths. (40)
# 91 :: But I know not at all
# that they, maddened,     robbed of their senses,
# astray in their actions     —that they praise to all men
# my wicked ways. (143)
# 92 :: Woe to them then
# when the Most High holds out     his dearest of gifts
# if they do not desist     first from their folly. (120)
# 93 :: Over the hillsides     this air upholds
# bright little creatures,     swarthy and dark-clad;
# bold of song,     they fare in flocks
# and loudly chirp. (147)
# 94 :: They tread the headlands,
# sometimes men’s houses. (49)
# 95 :: They name themselves. (21)
# 96 :: Sometimes I set forth     —when none would expect it—
# under turbulent waves,     seeking the depths,
# the floor of ocean. (120)
# 97 :: The sea is aroused,
# . (21)
# 98 :: foam is tossed up;
# the home of whales     roars and rages. (58)
# 99 :: Streams lash the shore,     violently dash
# up the steep strand     with sand and shingle
# and seaweed, when surging     I struggle and strive
# beneath the sea currents,     stir up the bottom,
# the broad sea deeps. (211)
# 100 :: Nor can I escape
# from the sea’s surface     until He permits
# who guides all my ways. (84)
# 101 :: O wise man, say,
# who is it drew me     from the sea’s embraces
# when the surges again     are stilled and quiet
# and calm the waves     which covered me first. (157)
# 102 :: Sometimes my Lord     constrains me close
# and forces me under     the broad bosom
# of the fertile fields     and holds me there,
# drives me into darkness,     where hard on my back
# the earth sits heavy. (200)
# 103 :: There is no escape
# from all that torment;     but the houses of heroes,
# their gabled halls,     I cause to tremble
# and shake the walls     of the dwellings of men,
# high over their heads. (186)
# 104 :: The air seems still
# in the skies above     and the waters quiet—
# until from confinement     upwards I thrust,
# even as He commands     who laid at the beginning
# my fetters upon me. (179)
# 105 :: I can never be free
# from the power that points     the path I follow. (69)
# 106 :: Sometimes from above     I rouse the surges,
# stir up the waters     and drive to the shore
# the flint-gray flood. (112)
# 107 :: Foaming the waves
# fight with the wall. (38)
# 108 :: Dim stands up
# the dune over the deep;     dark behind it
# blended with the sea     comes another surge. (102)
# 109 :: Together they meet     by the sea-mark there
# by the high ridges. (64)
# 110 :: Loud is the wooden ship,
# the noise of the sailors. (50)
# 111 :: Calmly await
# the steep stone cliffs     the battle of waters,
# the clashing waves,     when high the violence
# crowds on the headlands. (133)
# 112 :: There must the keel
# find bitter battle,     if the sea lifts it
# with all its men     in that terrible hour;
# till out of control,     robbed of its life,
# it rides through the foam     on the back of the waves. (208)
# 113 :: Then will be panic there,     manifest to mortals;
# . (52)
# 114 :: but I must obey,
# strong on my fierce way. (41)
# 115 :: Who will still that? (20)
# 116 :: Sometimes I rush     through the wan wet clouds
# that ride on my back,     scatter them wide
# with their streaming water. (119)
# 117 :: Sometimes I allow them
# to glide together. (41)
# 118 :: Great is the din,
# uproar over houses,     and loudest of crashes,
# when fiercely comes     cloud against cloud
# like sword against sword. (135)
# 119 :: Darkling spirits,
# swift over mortals,     sweat with fire,
# with gleaming flame     and fearful noises. (102)
# 120 :: Above mankind     with dreadful din
# they fare fighting;     they let fall then
# swart rattling streams     from out their bosom,
# water from within. (146)
# 121 :: Fighting moves on
# the terrible host;     panic arises,
# a mighty fear     in the hearts of mankind;
# horror in towns     when gleaming shoots
# the gliding demon     with sharp weapons. (181)
# 122 :: He is dull who dreads not     these arrows of death;
# he dies nonetheless     if the true Lord
# down through the rain,     straight from above
# lets fly the darts     of the fiery storm,
# its swift arrows. (201)
# 123 :: Few escape this
# who are reached by the darts     of the hostile rain. (69)
# 124 :: I stand in the van     of this battlefront
# when on I press     the column of cloud,
# push through the strife     in masterful might
# on the breast of the burns. (158)
# 125 :: Crowding in battle
# the high storm bursts. (41)
# 126 :: Then down I bend
# under the helm of the sky     close to the ground,
# bearing on my back     the burden I carry
# by the command of him,     the all-powerful Lord. (159)
# 127 :: Thus a mighty servant     I do battle by turns—
# sometimes under ground;     sometimes I must deep
# undermine the waves;     sometimes from on high
# I arouse the waters,     or rising aloft
# stir up the clouds. (206)
# 128 :: Widely I pass,
# swift and violent. (33)
# 129 :: Tell me my name,
# or who lifts and drives me,     when I may not rest,
# or who it is steadies me     when I become still. (119)
# 130 :: In those first days     my father and mother
# left me for dead:     there was no life yet,
# no life within me. (108)
# 131 :: Then a kindly kinswoman
# faithfully covered me     with her own clothing,
# held me and cherished,     kept me warmly,
# even as gently     as her own children—
# until beneath her,     as my destiny willed,
# I waxed into life     with my alien fellows. (245)
# 132 :: My friend and protector     nourished me then
# till I grew and grew able     to go forth by myself. (98)
# 133 :: Because of this now     her own dear children,
# sons and daughters,     were fewer, alas. (88)
# 134 :: Silent is my garment     when I tread the earth
# or dwell in the towns     or stir the waters. (93)
# 135 :: Sometimes my trappings     lift me up over
# the habitations of heroes     and this high air,
# and the might of the welkin     bears me afar
# above mankind. (152)
# 136 :: Then my adornments
# resound in song     and sing aloud
# with clear melody     —when I do not rest
# on land or water,     a moving spirit. (134)
# 137 :: I speak through my mouth     with many voices. (46)
# 138 :: Skilfully I sing     with many modulations,
# loud and strong, with various tunes. (80)
# 139 :: I sing as I must,     unhampered, unhindered. (45)
# 140 :: I am the nighttime     songster of old. (39)
# 141 :: I bring joy to the men     who dwell in the towns. (50)
# 142 :: When I sing out     with my flexible tones
# they sit at home silent. (67)
# 143 :: Tell me my name
# who brightly imitate     professional singers
# and loudly foretell     many welcome tidings. (107)
# 144 :: My beak was close fettered,     the currents of ocean,
# running cold beneath me. (79)
# 145 :: There I grew in the sea,
# my body close     to the moving wood. (62)
# 146 :: I was all alive     when I came from the water,
# clad all in black,     but a part of me white. (94)
# 147 :: When living, the air     lifted me up,
# the wind from the wave,     and bore me afar,
# up over the seal’s bath. (109)
# 148 :: Tell me my name. (16)
# 149 :: I move on my feet,     I break up the ground,
# the green meadows,     as long as I live. (87)
# 150 :: If life leaves me     I then bind fast
# the swarthy Welsh,     and sometimes better men. (87)
# 151 :: Sometimes I give drink     to a strong man
# from out of my bosom. (64)
# 152 :: Sometimes the stately dame
# treads me underfoot. (47)
# 153 :: Sometimes the Welsh girl,
# dark-haired slave     brought from afar,
# stupid and drunk,     on dark nights
# lifts me and presses me,     soaks me in water,
# warms me sometimes     kindly by the fire,
# her wanton hands     thrust in my bosom;
# turning often     sweeps through the dark. (278)
# 154 :: Say what my name is     who living ravage
# the land, and dead     am of service to men. (86)
# 155 :: I was little …     … my sister fed me. (38)
# 156 :: …
# Often I tugged     at four dear brothers,
# each one gave me     daily to drink,
# through a hole freely. (103)
# 157 :: I throve happily
# until I was older     and left all that
# to the swarthy herdsman. (81)
# 158 :: I traveled farther
# to the Welsh marches,     traversed the moors,
# bound under a beam. (85)
# 159 :: I had a ring on my neck,
# suffered woes on my way,     was forced to perform
# my share of labors. (95)
# 160 :: Often the goad hurt me
# sorely on my sides. (42)
# 161 :: But I was silent,
# never spoke out     to any man,
# if ever the pricks     were painful to me. (92)
# 162 :: I saw the creature,     of the arms-bearing kind,
# greedy for youth’s joys. (74)
# 163 :: As its due it let
# four nourishing fountains,     brightly shining,
# shoot forth noisily,     as is right and proper. (115)
# 164 :: Then spake a man,     who said to me:
# “The creature, if it lives,     will break up the hillside;
# if rent apart,     will bind the living.” (139)
# 165 :: I saw a woman     sitting alone. (32)
# 166 :: I saw them, all ten,     treading the turf,
# the six brothers     and their sisters too,
# living and lively. (106)
# 167 :: Their skins hung plainly,
# visibly manifest,     on the wall of the house,
# each and every one;     nor was any the worse,
# nor side the sorer,     though thus they must,
# despoiled of their raiment,     roused by the power
# of heaven’s Lord,     tear with their mouths
# the gray-green leaves. (287)
# 168 :: Their garment is renewed;
# having now come forth     they leave their coverings
# lying behind them     as they tread the ground. (126)
# 169 :: My neck is white,     my head is tawny
# and so are my sides. (59)
# 170 :: I am swift in my stride. (24)
# 171 :: I bear weapons of battle. (25)
# 172 :: On my back there is hair
# and the same on my cheeks. (51)
# 173 :: Over my eyes
# two ears stand up. (31)
# 174 :: I walk on my toes
# in the green grass. (37)
# 175 :: My doom is certain
# if anyone finds me,     if a slaughterous fighter
# finds me hidden     where I make my home,
# bold with my bairns. (131)
# 176 :: And there I abide
# with my little family     when the stranger comes
# to my very doors. (85)
# 177 :: Death is their doom. (20)
# 178 :: I must carry them off,     save them by flight
# with fear in my heart     away from my home. (91)
# 179 :: If he crowds me hard,     moving on his belly,
# I dare not abide     that fierce one in my burrow
# (that would be surely     not a good counsel)
# but bravely I must     with both hands and feet
# create a path     through the high hill. (231)
# 180 :: Easily I can save them,     my beloved kin,
# if I can bring my household     by a secret way
# through the hollow hill;     for there I need fear
# never a whit     the murderous whelp. (180)
# 181 :: If the hateful foe     follows me hard
# through the narrow track     he shall have no lack
# of the clash of battle     when we meet in the burrow;
# when I get to the top     of the hill and turn on him
# with weapons of war,     whom I formerly fled from. (250)
# 182 :: I saw a being     in wondrous wise
# hold its plunder     between its horns,
# a vessel of light,     of shining beauty,
# bringing it home,     a spoil of battle. (157)
# 183 :: It wished to build     a bower in the burg
# and cunningly place it     —if so might be. (86)
# 184 :: Then a wondrous being     came over the roof,
# known to all children     of mortal men,
# recovered the spoil     and then brought back
# the unwilling exile. (153)
# 185 :: Westward it went,
# hurrying home     after the battle. (53)
# 186 :: Dust rose to the skies;     dew fell on the ground;
# night departed     and none thereafter
# knew its way,     whither it went. (125)
# 187 :: The sea fed me;     the water-helm was over me,
# and waves covered me,     close to the ground. (94)
# 188 :: Often toward the water
# I opened my mouth. (41)
# 189 :: Now people will
# eat my meat. (28)
# 190 :: They want not my skin. (22)
# 191 :: When they rip my hide     with the point of a knife
# . (53)
# 192 :: Then they eat me uncooked. (26)
# 193 :: I saw a thing     in the dwellings of men
# that feeds the cattle;     has many teeth. (84)
# 194 :: The beak is useful to it;     it goes downwards,
# ravages faithfully;     pulls homewards;
# hunts along walls;     reaches for roots. (131)
# 195 :: Always it finds them,     those which are not fast;
# lets them, the beautiful,     when they are fast,
# stand in quiet     in their proper places,
# brightly shining,     growing, blooming. (185)
# 196 :: My beak is downward     and low I move
# and dig in the ground. (61)
# 197 :: The hoar foe of the forest
# directs my movements;     and so my master
# goes bent over,     the guide at my tail,
# drives across the field,     pushes me and crowds me,
# and sows in my swath. (187)
# 198 :: I go sniffing along,
# brought from the woodland,     stoutly fastened,
# borne on a wagon. (87)
# 199 :: I have many strange ways. (25)
# 200 :: I leave green on one side     and black on the other. (53)
# 201 :: Driven through my back     there hangs beneath
# a well-sharpened point;     on my head another,
# firm and forward-moving. (119)
# 202 :: What I tear with my teeth
# falls to the side,     if he serves me well,
# my lord who behind me     heeds me and guides me. (120)
# 203 :: My head is     forged with the hammer,
# hurt with sharp tools,     smoothed by files. (84)
# 204 :: I take in my mouth     what is set before me
# when girded with rings     I am forced to strike,
# hard against hard,     pierced from behind,
# must draw forth     what protects at midnight
# the heart’s delight     of my own lord. (224)
# 205 :: Sometimes I turn     backwards my beak,
# when, protector of treasure,     my lord wishes
# to hold the leavings     of those he had driven
# from life by battle-craft     for his own desire. (185)
# 206 :: I know a thing     with a single foot
# doing deeds of might. (59)
# 207 :: It travels not
# nor rides much,     nor can it fly
# through the clear air;     nor does ship carry it,
# a boat with nailed planks. (127)
# 208 :: It is nevertheless
# useful to its master     at many times. (58)
# 209 :: It has a heavy tail     and a small head
# and a long tongue. (59)
# 210 :: It has no tooth;
# part is of iron. (33)
# 211 :: It goes through a hollow. (25)
# 212 :: It swallows no water,     it eats nothing,
# it desires no fodder. (64)
# 213 :: Often notwithstanding
# it bears water aloft. (43)
# 214 :: It boasts not of life
# or of gifts from its chief. (49)
# 215 :: It obeys nonetheless
# its master’s word. (39)
# 216 :: In its name there are
# three real runes. (39)
# 217 :: Rād is the first. (17)
# 218 :: Bound with rings     I must readily obey
# from time to time     my servant and master
# and break my rest,     make noisily known
# that he gave me a band     to put on my neck. (172)
# 219 :: Often a man or a woman     has come to greet me,
# when weary with sleep,     wintry-cold, I answer him:
# (their hearts were angry):     “A warm limb
# sometimes bursts     the bound ring.”
# Nonetheless it is pleasant     to him, my servant,
# a half-witted man,     and to me the same,
# if one knows aught     and can then with words
# riddle my riddle     successfully. (360)
# 220 :: I have a puffed-out breast     and a swollen neck;
# I have a head     and a tall tail;
# I have eyes and ears     and a single foot,
# a rough hard bill     and a long neck
# and two sides;     hollow in the middle. (208)
# 221 :: My home is over men. (20)
# 222 :: I suffer much
# whenever he moves me     who stirs the forest,
# and rains and hard hail     beat on me as I stand,
# and frost freezes     and snow falls
# on me, hollow-bellied     . (176)
# 223 :: I was in there     where I saw something,
# a thing of wood,     wound a striving thing,
# the moving beam     —it received battle wounds,
# deep injuries;     spears caused the hurts
# of this thing;     and the wood was fast bound
# cunningly. (235)
# 224 :: One of its feet
# was stable, fixed;     the other worked busily,
# played in the air,     sometimes near the ground. (113)
# 225 :: A tree was nearby,     that stood there hung
# with bright leaves. (64)
# 226 :: I saw the leavings
# of the arrow-work     brought to my lord
# where heroes sat     over their drinks. (99)
# 227 :: I know a something     that stands firm on the ground,
# deaf and dumb,     that by day often swallows
# from the servant’s hand     useful gifts. (142)
# 228 :: Sometimes in the towns     the dark thane,
# swarthy and dun-faced,     sends more of these
# into its mouth,     dearer than gold,
# which men of rank     often desire,
# kings and queens. (181)
# 229 :: I will not now yet
# name his nature     who for use and profit
# of doughty men     makes what the dumb thing
# (that dun-faced nitwit)     first swallows up. (153)
# 230 :: I was alive but said nothing;     even so I die. (48)
# 231 :: Back I came before I was. (25)
# 232 :: Everyone plunders me,
# keeps me confined,     and shears my head,
# bites my bare body,     breaks my sprouts. (107)
# 233 :: No man I bite     unless he bites me;
# many there are     who do bite me. (72)
# 234 :: The books tell us     that this thing has been
# among mankind     through many ages
# clear and manifest. (102)
# 235 :: A special power
# it has much greater     than any men know. (58)
# 236 :: It wishes to seek     all living beings
# one by one;     then goes its way;
# no second night     in the same place;
# but homeless roves     for ever and aye,
# the path of exile. (173)
# 237 :: It is none the poorer. (22)
# 238 :: It has neither foot nor hand,     nor touches the ground,
# nor two eyes nor mouth     nor speaks with men. (105)
# 239 :: It has no mind,     but the books say
# it is quite the poorest     of all creatures
# that were ever begotten     according to nature. (131)
# 240 :: It has no soul nor life,     but makes its way
# far and wide     through this wonderful world
# It has no blood, no bone,     yet gives aid and comfort
# to many men     the wide world over. (185)
# 241 :: It never reached to heaven,     it may not to hell,
# but forever it must     live by the teachings
# of the King of Glory. (119)
# 242 :: Long is it to relate
# how its way of life     will go thereafter
# fate’s crooked ways. (84)
# 243 :: This is a marvelous
# thing to say:     it is all true
# that ever with words     is told about it. (95)
# 244 :: It has no limit. (16)
# 245 :: It lives nevertheless. (22)
# 246 :: If you can straightway     rede this riddle
# with true words,     tell what its name is. (87)
# 247 :: I saw four things     in beautiful fashion
# journeying together. (63)
# 248 :: Dark were their tracks,
# the path very black. (44)
# 249 :: Swift was its moving,
# faster than birds     it flew through the air,
# dove under the wave. (89)
# 250 :: Labored unresting
# the fighting warrior     who showed them the way,
# all of the four,     over plated gold. (106)
# 251 :: I was along the sand,     near the sea-wall,
# at the water’s edge,     and firmly fixed
# in the place of my birth. (112)
# 252 :: Few men there were
# who looked upon     my home of solitude. (59)
# 253 :: But at every dawn     the dark waves held me
# in their watery embrace. (69)
# 254 :: Little did I think
# that ever I should     sooner or later
# speak without mouth     over the mead-bench,
# exchange words. (118)
# 255 :: This is a kind of wonder,
# curious for the minds     of such as understand not
# how the point of a knife     and a right hand
# and a prince’s thought     and the point itself
# purposely fashioned it,     that I with thee
# should boldly declare,     for us two alone,
# a spoken message,     so that no other men
# should further grasp     the words of our speech. (354)
# 256 :: A moth ate words. (17)
# 257 :: To me it seemed
# a remarkable fate,     when I learned of the marvel,
# that the worm had swallowed     the speech of a man,
# a thief in the night,     a renowned saying
# and its place itself. (187)
# 258 :: Though he swallowed the word
# the thieving stranger     was no whit the wiser. (77)
# 259 :: An enemy came     and took away my life
# and my strength also     in the word; then wetted me,
# dipped me in water;     then took me thence;
# placed me in the sun,     where I lost all my hair. (190)
# 260 :: The knife’s edge cut me—     its impurities ground away;
# fingers folded me. (75)
# 261 :: And the bird’s delight
# with swift drops     made frequent traces
# over the brown surface;     swallowed the tree-dye
# with a measure of liquid;     traveling across me,
# left a dark track. (185)
# 262 :: A good man covered me
# with protecting boards,     which stretched skin over me;
# adorned me with gold. (101)
# 263 :: Then the work of smiths
# decorated me with strands     of woven wire. (68)
# 264 :: Now may the ornaments     and the red dye
# and the precious possessions     everywhere honor
# the Guardian of peoples. (116)
# 265 :: It were otherwise folly. (24)
# 266 :: If the sons of men     wish to enjoy me,
# they will be the safer     and surer of victory
# and the stronger of heart     and the happier of mind
# and the wiser of spirit. (167)
# 267 :: They will have more friends,
# dearer and closer,     truer and better,
# nobler and more devoted,     who will increase
# their honor and wealth,     with love and favors
# and kindnesses surround them,     and clasp them close
# with loving embraces. (242)
# 268 :: I am a help to mortals. (23)
# 269 :: My name is a glory
# and salvation to heroes,     and myself am holy. (67)
# 270 :: Beautifully made     in many ways
# is this our world,     cunningly adorned. (75)
# 271 :: I saw a strange thing     singing in a house;
# its shape was more wonderful     than aught among men. (100)
# 272 :: Its beak was underneath,     its feet and hands birdlike,
# yet fly it cannot     nor walk at all. (96)
# 273 :: Yet eager for movement     it starts to work
# with various arts. (63)
# 274 :: It often goes around
# again and again     among noble men. (57)
# 275 :: It sits at the banquet-board,     awaits its turn
# till comes its time     to display its skill
# among those who are near. (120)
# 276 :: It partakes of nothing
# that the men there     have for their pleasure. (70)
# 277 :: Brave, eager for glory     it remains dumb,
# yet it has in its foot     beautiful sounds,
# a glorious gift of song. (113)
# 278 :: Wondrous it seems to me
# how this very thing     can play with words
# through its foot beneath     adorned with trappings. (120)
# 279 :: It has on its neck     when it guards its treasure,
# bare, proud with rings,     its two companions,
# brother and sister. (119)
# 280 :: It’s a great thing surely
# for a wise singer     to think what this is. (70)
# 281 :: It is a splendid thing     when one knows not its ways. (55)
# 282 :: It sings through its sides. (27)
# 283 :: Its neck is curved. (19)
# 284 :: and cunningly wrought. (22)
# 285 :: It has two shoulders,
# which are sharp, on its back. (51)
# 286 :: It follows its fate,
# when it stands by the road,     so handsomely there,
# tall and bright-hued;     useful to good men. (119)
# 287 :: Uuob is my name     read in reverse. (36)
# 288 :: I’m a beautiful thing,     shaped for fighting. (47)
# 289 :: Whenever I am bent     and there flies from my bosom
# the poisonous dart     I am all eager
# to drive afar off     the deadly bale. (129)
# 290 :: Whenever my master     who shaped me that pain
# loosens my limb     I am longer than before,
# till I spit forth again     the death-blended bane,
# that very fell poison     which erst I swallowed. (193)
# 291 :: This that I speak of     leaves no man easily
# if that which flies from me     should ever touch him,
# so that perforce he purchases     surely with his life
# that fatal drink,     a full atonement. (195)
# 292 :: Unstrung I obey     no man, but only
# when skilfully tied. (57)
# 293 :: Tell me my name. (16)
# 294 :: I saw a tree     with bright branches
# stand high in a grove. (60)
# 295 :: The tree was happy,
# the growing wood. (37)
# 296 :: Water and earth
# fed it well,     till wise with time
# it met with a change:     it was deeply hurt,
# dumb with bonds,     covered with wounds,
# but adorned in front     with dark ornaments. (186)
# 297 :: Now it clears the way     for a treacherous foe
# through the might of its head. (78)
# 298 :: By storm they plunder
# the hoard together. (41)
# 299 :: Eager was the rear
# and active in aid     if the van met danger. (63)
# 300 :: None could venture     in difficult places. (43)
# 301 :: I grew up in a field,     lived where the earth
# and the sky fed me,     till old in years
# they turned me aside,     those who hated me,
# from the way that was mine,     that I held while I lived. (194)
# 302 :: They altered my fashion,     took me from the ground
# and against my nature     made me bow at times
# to a slayer’s will. (119)
# 303 :: Now in my master’s hand
# . (25)
# 304 :: cares for me well     carries me in battle
# with skill by his will. (66)
# 305 :: It is widely known
# that I among the bold     with a thief’s craft
# . (67)
# 306 :: sometimes openly     against a fastness
# I break forth where     before was peace. (81)
# 307 :: Swift in movement     he turns in haste
# away from that place,     the warrior who knows
# what are my ways. (105)
# 308 :: Say what my name is. (20)
# 309 :: I am a lonely thing,     wounded with iron,
# switten by sword,     sated with battle-work,
# weary of blades. (106)
# 310 :: Often I see battle,
# fierce combat. (34)
# 311 :: I foresee no comfort,
# no help will come for me     from the heat of battle,
# until among men     I perish utterly;
# but the hammered swords     will beat me and bite me,
# hard-edged and sharp,     the handiwork of smiths,
# in towns among men. (238)
# 312 :: Abide I must always
# the meeting of foes. (40)
# 313 :: Never could I find
# among the leeches,     where people foregather,
# any who with herbs     would heal my wounds;
# but the sores from the swords     are always greater
# with mortal blows     day and night. (201)
# 314 :: A thing there is     strangely begotten,
# furious and fierce;     runs a violent course
# rages grimly,     moves over the ground,
# is mother of many     marvelous creatures. (170)
# 315 :: Moving beautifully,     it is ever striving;
# low-lying is its close grip. (73)
# 316 :: None to another
# can fairly with wise words     describe its features
# or say how manifold     is the multitude of its kin. (121)
# 317 :: Its ancient origin     the Father watched over,
# beginning and end,     and his only Son also,
# glorious child of God     . (121)
# 318 :: Mighty in strength     the mother is;
# supported marvelously,     laden with food,
# adorned with treasures,     precious to heroes;
# her might is multiplied,     strength made manifest,
# her face is honored     with happy usefulness;
# a fair bright jewel     for the proud to wear;
# cleanly and bountiful;     mighty in craft. (320)
# 319 :: It is dear to the prosperous,     to the poor soothing,
# goodly, excellent;     boldest and strongest,
# greediest and eagerest—     treads over the ground—
# of all that is grown up     underneath the sky
# and that the sons of men     ever saw with their eyes. (255)
# 320 :: So that glory weaves     the might of mortals,
# although wise of mind     . (74)
# 321 :: a man more knowing of heart,     a crowd of wonders. (52)
# 322 :: Than earth it is harder,     than heroes older,
# than gifts readier,     than gems dearer;
# beautifies the world;     increases in fruits;
# blots out crime …
# often casts from without     a single covering
# wondrously beautiful,     over all mankind,
# so that throughout the world     men are astonished. (298)
# 323 :: Me the wet ground,     exceeding cold,
# first brought forth     from within itself. (82)
# 324 :: Neither am I wrought     of woolen fleece
# nor of hairs, with skill;     I know it in my mind. (93)
# 325 :: I have no winding wefts     nor any warp in me;
# nor with strong rods     does the thread resound for me,
# nor the whirring shuttle     move across me,
# nor the weaver’s rods     anywhere smite me. (194)
# 326 :: Worms do not weave me     with fatal wiles
# which fairly adorn     the fine yellow web. (86)
# 327 :: Yet nevertheless     the wide world over
# one will call me a joyful     garment for heroes. (90)
# 328 :: Say now truly,     you cunning sage,
# learned in language,     what this garment may be. (87)
# 329 :: I‘m a wonderful thing     shaped for fighting,
# beautifully dressed,     dear to my master. (90)
# 330 :: Gay colored is my byrnie;     bright wire that my wielder
# who guides me gave me,     embraces the death-gem,
# who sometimes to strife     directs my wanderings. (159)
# 331 :: Then I bring home treasure     through the shining day,
# handiwork of smiths,     gold to the dwellings. (103)
# 332 :: Often I slay     living warriors
# with weapons of war. (53)
# 333 :: A king adorns me
# with jewels and silver     and honors me in the hall,
# nor withholds my praise,     publicly proclaims
# my merits before men,     when they drink their mead;
# sometimes holds me back     or frees me when weary
# with going into battle. (247)
# 334 :: I have often hurt another
# at the hands of his friend. (53)
# 335 :: I am far and wide hated,
# accursed among weapons. (48)
# 336 :: I must never hope
# that a son will avenge me     on the life of my slayer
# if ever an enemy     assails me in battle;
# nor will my kin be increased,     the breed whence I sprang—
# unless bereft of my lord     I might change to a new,
# turn from the owner     who first rewarded me. (277)
# 337 :: Henceforth I am fated     if I follow a (new) lord
# to do battle for him     as I did for the other,
# for my prince’s pleasure,     that I must forego
# the wealth of children     and know no woman;
# for he who held me     of yore in thrall
# denies me that bliss. (257)
# 338 :: I must therefore enjoy
# single, alone,     the wealth of heroes. (63)
# 339 :: Often foolish in my finery     I enrage a woman,
# diminish her desire;     her tongue abuses me;
# she hits me with her hands,     reviles me with words,
# intones a curse. (167)
# 340 :: I like not this contest.… (25)
# 341 :: I protect my hearth,     my hoard and my home,
# surrounded by strands     and filled within
# with excellent treasures. (116)
# 342 :: Often by day
# I spit abroad     the terror of spears. (52)
# 343 :: My success is the greater     the more I am filled. (51)
# 344 :: My master sees this,     how darts fly from within me. (54)
# 345 :: Sometimes I swallow     the swart dark weapons,
# the poisoned darts. (67)
# 346 :: My entrails are good,
# precious to warriors,     the hoard that I hold. (70)
# 347 :: Many remember     what goes through my mouth. (45)
# 348 :: I was an armed fighter. (23)
# 349 :: Now a young home-dweller
# covers me proudly     with twisted wires,
# with gold and silver. (88)
# 350 :: Sometimes men kiss me. (22)
# 351 :: Sometimes with my song     I summon to battle
# happy comrades. (61)
# 352 :: Sometimes a steed carries me
# over the marches. (46)
# 353 :: Sometimes a sea-horse
# bears me over waves     with my bright trappings. (71)
# 354 :: Sometimes a maiden     fills my ring-adorned bosom. (51)
# 355 :: Sometimes I must lie     hard and headless
# stripped on the tables. (66)
# 356 :: Sometimes I hang,
# with ornaments proud,     on the wall where men drink. (72)
# 357 :: Sometimes a good weapon,     the warriors bear me,
# riding on horseback,     with treasure laden,
# I must breathe in the breath     of a man’s breast. (148)
# 358 :: Sometimes with my music     I summon proud warriors
# to drink their wine. (72)
# 359 :: Sometimes with my voice
# I rescue the booty,     put foe to flight. (66)
# 360 :: I am atheling’s     shoulder-companion,
# a warrior’s comrade,     dear to my master,
# a fellow of kings. (102)
# 361 :: His fair-haired lady
# sometimes will lay     her hand upon me,
# a prince’s daughter,     noble though she be. (107)
# 362 :: I have on my breast     what grew in the grove. (47)
# 363 :: Sometimes I ride     on a proud steed
# at the army’s head. (57)
# 364 :: Hard is my tongue. (18)
# 365 :: Often I bring     a reward for his words
# to the singer after his song. (70)
# 366 :: Good is my note,
# and myself am dark-colored. (44)
# 367 :: Say what my name is. (20)
# 368 :: I am an atheling’s     possession and delight (45)
# 369 :: But I stood upright     where I [was],
# I and my brother. (56)
# 370 :: Both of us were hard. (21)
# 371 :: The place was noble     where we two stood,
# the higher in honor. (64)
# 372 :: The holt often hid us,
# a shelter of trees     in the dark nights,
# shielded us from showers. (91)
# 373 :: The Lord made us both. (22)
# 374 :: After us two large ones,     our kin will now follow us,
# younger brothers     will drive us from our home. (106)
# 375 :: I am unique in the world. (25)
# 376 :: My back itself
# is dark and wonderful. (37)
# 377 :: I stand on the wood,
# at the end of the board. (45)
# 378 :: My brother is not here,
# but brotherless now     I must keep my place
# at the end of the board     and firmly stand. (114)
# 379 :: I know not where     my brother is now
# or where he dwells     on the bosom of earth,
# who formerly dwelt     high by my side. (124)
# 380 :: We stood together     in making war;
# neither alone     declared his strength,
# else were we in battle     both unavailing. (121)
# 381 :: Now strange beings     tear into me,
# injure my insides. (55)
# 382 :: I cannot escape. (16)
# 383 :: On the tracks he will find     success, he who seeks it,
# . (58)
# 384 :: his soul’s profit. (18)
# 385 :: Old with many days     over deep streams;
# sometimes he would climb     the steep hills
# up in his homeland;     sometimes he went back
# into deep dales,     seeking for safety,
# strong of stride. (192)
# 386 :: He dug into stony ground,
# frozen hard;     sometimes he shook the frost
# from his bright white hair. (99)
# 387 :: I rode with the eager ones
# until my younger brother     seized the seat of joy
# and drove me off     from my own home. (117)
# 388 :: Then the dark iron     wounded me within;
# no blood flowed forth,     no gore from within
# though the sharp-edged steel     bit into me hard. (139)
# 389 :: I mourned not the time,     nor wept for the wound,
# nor could I avenge     my heavy fate,
# a life for a life:     but I suffer the torment
# of all that bit the shield. (165)
# 390 :: Now I swallow the black,
# the wood and water. (44)
# 391 :: I embrace within me
# what falls from above     on me where I stand
# (it is something dark). (89)
# 392 :: I have one foot. (16)
# 393 :: Now the ravaging foe     plunders my treasure
# who bore once widely     the wolf’s companion. (92)
# 394 :: What came from within me     moves on and on,
# steps on the stout board     . (76)
# 395 :: I war oft against wave     and fight against wind,
# do battle with both,     when I reach to the ground,
# covered by the waters. (126)
# 396 :: The land is strange to me. (26)
# 397 :: I am strong in the strife     if I stay at rest. (48)
# 398 :: If I fail at that,     they are stronger than I
# and forthwith they wrench me     and put me to rout. (100)
# 399 :: They would carry away     what I ought to defend. (49)
# 400 :: I withstand them then     if my tail endures
# and the stones hold me fast. (73)
# 401 :: Ask what my name is. (20)
# 402 :: Beautifully made     in many ways
# is this our world,     cunningly adorned. (75)
# 403 :: Marvelous is its motion,     I saw this device
# grind against the gravel,     crying out as it went. (99)
# 404 :: This marvelous thing     had no sight nor feeling,
# neither shoulders nor arms. (78)
# 405 :: One foot only
# had this curious device     to journey along on,
# to move over the fields. (87)
# 406 :: It had many ribs,
# its mouth was midway. (39)
# 407 :: Useful to mortals,
# it bears abundance     of food to the people,
# brings them plenty     and pays to men
# annual tribute     which all enjoy,
# the high and the lowly. (163)
# 408 :: Explain if you can,
# who are wise in words,     what this thing may be. (70)
# 409 :: I am honored among men     both near and far;
# brought from the groves     and inhabited hills,
# from vales and from downs. (121)
# 410 :: By day I was borne
# on wings through the air     and happily wafted
# to the shelter of roofs. (91)
# 411 :: Then they bathed me in butts. (29)
# 412 :: Now I bind and I scourge     and I overthrow
# the young to the ground     and the elders sometimes,
# and this he soon finds     who takes me on
# and attacks me with violence;     he falls on his back
# unless he flees from his folly. (228)
# 413 :: Robbed of his strength,
# though strong in speech,     he is deprived of his powers,
# and control of his mind,     of his feet and his hands. (138)
# 414 :: Ask what my name is     who bind men to the ground,
# the foolish after fighting,     in broad daylight. (102)
# 415 :: A thing came marvelously     moving over the waves,
# comely from the keel up. (76)
# 416 :: It called out to the land,
# loudly resounding. (45)
# 417 :: Its laughter was horrible,
# awful in its place. (46)
# 418 :: Its edges were sharp;
# hateful it was,     and sluggish to battle,
# bitter in its hostile deeds. (94)
# 419 :: It dug into shield-walls,
# hard, ravaging. (41)
# 420 :: It spread mischievous spells. (29)
# 421 :: It spoke with cunning craft     about its creation:
# “Dearest of women     is indeed my mother;
# she is my daughter     grown big and strong. (139)
# 422 :: It is known to men of old,     among all people,
# that she shall stand up beautifully     everywhere in the world.” (114)
# 423 :: There’s a bit of earth     beautifully sown
# with the hardest and the sharpest     and the grimmest that men own. (112)
# 424 :: Cut and cleaned,     turned and dried;
# pleached and wound;     bleached and bound;
# adorned and arrayed     and borne away
# to the doors of men. (142)
# 425 :: Joy is within
# for living creatures. (35)
# 426 :: It delays and it stays
# a long long while. (41)
# 427 :: They live in joy
# and naught gainsays. (37)
# 428 :: But after the death
# they start talking big,     chattering, chittering. (71)
# 429 :: It is hard for a wise man     to say what this is. (50)
# 430 :: A creature came     where many men
# sat at council     with wise hearts. (71)
# 431 :: It had one eye     and its ears were two;
# it had two feet     and twelve hundred heads,
# a back and a belly     and two hands,
# arms and shoulders,     one neck,
# and two sides. (174)
# 432 :: Say what I’m called. (20)
# 433 :: Not silent is my hall,     nor I myself am loud
# . (49)
# 434 :: for us two the Lord ordained
# our ways together. (47)
# 435 :: I am swifter than he
# and at times stronger;     he is more enduring. (68)
# 436 :: Often I rest;     he must run on. (33)
# 437 :: With him is my home     all my life long. (41)
# 438 :: If we two are parted     my death is destined. (46)
# 439 :: Came sixty riding on horseback to the seashore. (47)
# 440 :: Eleven rode on stately steeds; four white horses. (49)
# 441 :: However they tried they could not cross the water,
# for it was too deep and the banks too high and the currents too strong. (122)
# 442 :: So they climbed on a wagon, with their horses under the pole. (61)
# 443 :: Then a horse bore them all, horses and proud men with spears,
# across the bay and on to the land,
# though no ox drew it, nor powerful slaves,
# nor stout steed—neither swam nor walked
# on the ground under the strange burden,
# nor stirred the waters, nor flew in the air, nor turned back. (281)
# 444 :: Yet the men crossed the stream
# and their steeds also, from the high bank. (73)
# 445 :: So they strode up on the other side bravely,
# men and horses, safe and sound from the water. (91)
# 446 :: He sat at his wine     with his two wives
# and his two sons     and his two daughters,
# the beloved sisters,     and their two sons,
# goodly first born. (149)
# 447 :: The father of each
# of these noble ones     was there and there also
# an uncle and a nephew. (90)
# 448 :: Five in all,
# men and women,     were sitting together. (54)
# 449 :: I saw two captives     carried in the house
# under the hall-roof;     sturdy were they both;
# companions they were,     fast bound together. (138)
# 450 :: Close to one of them     was a dark-skinned slave. (50)
# 451 :: She controlled them both     by fast fetters. (45)
# 452 :: I was a young woman,     a fair-haired lady,
# and at the same time     a peerless warrior;
# I flew with the birds     and swam in the sea,
# dove under the wave,     and was dead among fishes,
# and I walked on the ground. (216)
# 453 :: I had a living soul. (20)
# 454 :: I am a lordly, thing     known to nobles,
# and often I rest,     famous among peoples,
# the mighty and the lowly;     I travel widely
# and to me first a stranger     remains to my friends
# the delight of plunderers,     if I am to have
# success in the cities     or bright reward. (275)
# 455 :: Now wise men     exceedingly love
# my presence. (46)
# 456 :: To many I shall
# declare wisdom. (31)
# 457 :: There they speak not,
# none the world over. (42)
# 458 :: Though now the sons of men
# who live on the earth     eagerly seek
# the tracks that I make. (89)
# 459 :: I sometimes conceal
# those paths of mine     from all mankind. (61)
# 460 :: I’m a wonderful thing;     I vary my voice:
# I bark like a dog,     I bleat like a goat,
# I quack like a goose,     I shriek like a hawk;
# I imitate the eagle,     the gray one, the cry
# Of the fighting bird;     sometimes the kite’s voice
# is familiar to my mouth,     or the sea-mew’s song,
# where I happily sit. (308)
# 461 :: GIFT is my name,
# OAK and RIDING     and the GOD helps,HAIL and ICE. (67)
# 462 :: Now you have my name,
# as those six letters     clearly betoken. (63)
# 463 :: I saw there     two beautiful creatures
# openly playing     the game of love. (76)
# 464 :: If the affair prospered,     the fair-haired one
# proudly arrayed,     received her due fulness. (95)
# 465 :: Now I can tell     the assembled bookmen
# the names of both     in runic letters. (80)
# 466 :: There shall be NEED,     two of these,
# and the bright ASH tree,     one on the line,
# and then two OAKS     and two HAILS likewise. (130)
# 467 :: Whoever has unlocked     with the power of the key
# the clasps of the chest     which held the riddle
# cunningly hidden     from the learned in runes—
# now is revealed to them     here as they drink
# how those two of low minds     are called by name. (246)
# 468 :: I saw the wight     going on its way. (37)
# 469 :: It was splendidly,     wonderfully arrayed. (43)
# 470 :: The wonder was on the wave;     water became bone. (50)
# 471 :: I saw …     S R O
# H high-spirited, with gleaming head
# rinning swiftly     over the fair land;
# it had on its back     warlike strength. (134)
# 472 :: N O M     rode not-mailed
# A G E W     far traveling it bore
# strong on its way     a bold C O
# F O A H     the course was the brighter,
# the journey of these. (155)
# 473 :: Say what I am called. (21)
# 474 :: I saw W and I     going over the plain
# bearing B E.     For them both as they went
# was the owner’s joy;     H and A
# very strong. (128)
# 475 :: TH and E;
# the F and A rejoiced;     flew over EA
# S and F     of the people themselves. (86)
# 476 :: I saw a thing     moving over the wave [or ways]. (49)
# 477 :: It was gorgeously,     wondrously arrayed. (42)
# 478 :: It had four feet     beneath its belly[and eight man hwm     wiif mxlkfw
# f horse qxxs—up on its back.] (102)
# 479 :: It had two wings     and twelve eyes
# and six heads. (51)
# 480 :: Tell what it was. (17)
# 481 :: It moved over the water;     nor was it a bird alone,
# but there was a likeness     of each of these:
# a horse and a man,     a dog and a bird,
# and also the shape of a woman. (172)
# 482 :: You know
# how to say, if you can,     who know the truth,
# just how the nature     of the thing may go. (101)
# 483 :: I saw a swift one     going along the path (42)
# 484 :: I’m a wonderful thing,     a joy to women,
# to neighbors useful. (63)
# 485 :: I injure no one
# who lives in a village     save only my slayer. (63)
# 486 :: I stand up high     and steep over the bed;
# underneath I’m shaggy. (66)
# 487 :: Sometimes ventures
# a young and handsome     peasant’s daughter,
# a maiden proud,     to lay hold on me. (102)
# 488 :: She seizes me, red,     plunders my head,
# fixes on me fast,     feels straightway
# what meeting me means     when she thus approaches,
# a curly-haired woman. (155)
# 489 :: Wet is that eye. (16)
# 490 :: Splendidly it hangs     by a man’s thigh,
# under the master’s cloak. (67)
# 491 :: In front is a hole. (19)
# 492 :: It is stiff and hard;     it has a goodly place. (48)
# 493 :: When the young man     his own garment
# lifts over his knee,     he wishes to visit
# with the head of what hangs     the familiar hole
# he had often filled     with its equal length. (179)
# 494 :: I have heard of something     wax in a corner,
# swell and pop,     lift up the covers. (85)
# 495 :: A proud-minded woman     seized with her hands
# that boneless thing,     a prince’s daughter;
# covered with her dress     the swelling thing. (139)
# 496 :: A youth came along     to where he knew
# she stood in a corner. (62)
# 497 :: Forth he strode,
# a vigorous young man,     lifted up her own
# dress with his hands,     thrust under her girdle
# something stiff     as she stood there;
# worked his will;     both of them shook. (191)
# 498 :: A thane hurried up,     useful at times,
# a capable servant;     nonetheless he grew tired
# from time to time,     though strong at first,
# weary with work. (153)
# 499 :: Beneath the girdle
# there began to grow     what often good men
# love heartily     and buy with money. (100)
# 500 :: Often a goodly damsel,     a lady, locked me
# close in a chest. (62)
# 501 :: Sometimes with her hands
# she took me out     and gave me to her lord,
# a fine chieftain,     as he commanded her. (112)
# 502 :: Then he thrust his head     well inside me,
# up from below,     into the narrow part. (84)
# 503 :: If the strength prevailed     of him who received me,
# adorned as I was,     something or other rough
# was due to fill me. (120)
# 504 :: Guess what I mean. (18)
# 505 :: I am hard and sharp,     strong in entering,
# bold in coming out,     good and true to my lord. (94)
# 506 :: I go in underneath     and myself open up
# the proper way. (57)
# 507 :: The warrior is in haste
# who pushes me from behind     a hero with his dress. (76)
# 508 :: Sometimes he draws me out,     hot from the hole. (49)
# 509 :: Sometimes I go back     in the narrow place—
# I know not where. (62)
# 510 :: A southern man
# drives me hard. (30)
# 511 :: Say what my name is. (20)
# 512 :: A warrior is wondrously     brought into the world
# for the use of lords     by two dumb things;
# brightly extracted,     which for his hurt
# foe bears against foe. (161)
# 513 :: Strong though he is
# a woman binds him. (38)
# 514 :: He obeys them well,
# serves them quietly,     if maids and men
# tend him duly,     feed him fairly. (97)
# 515 :: He exalts them in comfort     for their joy in life,
# grimly rewards one     who lets him grow proud. (100)
# 516 :: I saw the thing;     its belly was at the back
# hugely puffed out. (65)
# 517 :: A servant attended it,
# a man of might. (38)
# 518 :: And much had it suffered
# when that which filled it     flew from its eye. (73)
# 519 :: It does not always die     when it has to give
# what is in it to another. (72)
# 520 :: But there comes again
# reward to its bosom. (42)
# 521 :: Its bloom returns. (18)
# 522 :: It creates a son;     it is its own father. (43)
# 523 :: I saw a marvelous thing;     it had a big belly
# mightily swollen. (65)
# 524 :: A servant followed it,
# powerful and strong of hand. (51)
# 525 :: Great I thought him,
# a goodly warrior. (38)
# 526 :: He seized hold at once,
# with heaven’s tooth     . (49)
# 527 :: blew in its eye. (16)
# 528 :: It barked,
# weakened willingly;     would none the less
# . (56)
# 529 :: I’m a wonderful thing,     cannot say a word
# or speak for men     though I have a mouth
# a broad belly     . (107)
# 530 :: I was on a ship     and more of my kindred. (43)
# 531 :: renewed
# That is mother     of many kindreds,
# of the best,     of the darkest,
# of the dearest     that the children of men
# throughout the bosom of earth     own with joy. (169)
# 532 :: We here on earth     cannot live at all
# unless we enjoy     what those children do. (83)
# 533 :: This is something for all mortals     to reflect on,
# all learned men,     what this thing is. (93)
# 534 :: Often shall I prove     to be a thing of value
# to the joys of the hall     when I am brought forth,
# happy with gold,     where men are drinking. (144)
# 535 :: Often in the bower     the faithful servant
# kisses my mouth     where we two are together … (91)
# 536 :: I have heard     of a splendid thing,
# of the Lord of peoples,     a word of incantation …
#
# Several defective lines and then the conclusion:
#
#
#
#
#
#                               I have become
# a teacher of peoples,     live an eternal life
# in many lands,     while men inhabit
# the bosom of earth. (292)
# 537 :: I have often seen it
# adorned with gold     where men were drinking,
# with treasures and silver. (94)
# 538 :: Say if you can,
# if you are wise enough,     what this thing is. (63)
# 539 :: I am a strong man’s property     clothed in red [gold?]. (56)
# 540 :: My place was first     the hard steep ground
# with fair bright herbs. (68)
# 541 :: Now I am the leavings of harsh things,
# the fire and the file. (61)
# 542 :: I am closely constrained
# and honored with wires. (48)
# 543 :: He sometimes weeps,
# the bearer of gold,     because of my grasp
# when I shall ravage … (85)
# 544 :: Ancient my lineage     . (24)
# 545 :: I lived in towns     after the keeper of fire
# . (47)
# 546 :: encircled with flame
# purified by fire. (38)
# 547 :: Now earth’s brother,
# an enemy, guards me,     who was first for me
# a bringer of sorrow. (87)
# 548 :: Full well I remember
# who in the beginning     drove my lineage,
# destroyed all the world. (88)
# 549 :: I may do him no harm,
# but I raise up captivity     from time to time,
# the wide world over. (90)
# 550 :: I have many glories,
# no little strength     in all the land,
# but I must conceal     from every man
# the secret power     of precious skill
# and the path I follow. (160)
# 551 :: Tell what my name is. (21)
# 552 :: I was the boast of brown [things],     a tree in the forest,
# a fine living thing     and a fruit of the field,
# a foundation of joy,     a woman’s message,
# gold in the homes. (173)
# 553 :: Now I am a warrior’s
# happy weapon     with a ring … (51)
# 554 :: Smith …
# higher than heaven …
#                               … than the sun
# . (75)
# 555 :: sharper than salt …
# dearer than all this light,     brighter than … (67)
# 556 :: It seemed strange to me,     a wolf held by a lamb;
# the lamb fell …     and disemboweled the wolf. (98)
# 557 :: As I stood and watched     I beheld great glory:
# There stood two wolves     troubling a third—
# four feet had they;     with seven eyes they saw. (144)
# 558 :: To my people it is as if one should give them a gift;
# They will oppress him if he comes into the throng
# It is otherwise with us. (128)
# 559 :: Wolf is on an island, I on another;
# The island is firm, encompassed by marsh;
# There are fierce men there on the island;
# They will (etc. (135)
# 560 :: It is otherwise with us. (24)
# 561 :: for my Wolf with far-wandering longings;
# Then it was rainy weather and I sat tearful,
# When the man bold in war surrounded me with boughs:
# It was joy for me so far, yet it was also pain. (185)
# 562 :: Wolf, my Wolf, thy hopes
# Have made me sick, thy rare visits
# A grieving spirit, not at all want of food. (103)
# 563 :: Dost thou hear, Eadwacer? (25)
# 564 :: Brisk cub of us two
# Wolf bears to the wood. (43)
# 565 :: Easily one tears asunder what was never united,
# Our song together. (66)

# %%
grammar = r"""
    NBAR:
        {<NN.*|JJ>*<NN.*>}  # Nouns and Adjectives, terminated with Nouns
        
    NP:
        {<NBAR>}
        {<NBAR><IN><NBAR>}  # Above, connected with in/of/etc...
"""
npchunker = nltk.RegexpParser(grammar)

# %%
def get_pos_tags(tokens):
        return nltk.tag.pos_tag(tokens)

def get_pos_tree(tokens):
    postoks = get_pos_tags(tokens)
    tree = npchunker.parse(postoks)
    return tree

def tokenize_words(txt):
    return nltk.tokenize.word_tokenize(txt)

# %%
get_pos_tags(tokenize_words(riddle_sentences[2]))
# JJ, NN, NNS
# Out:
# [(u'Smoke', 'NNP'),
#  (u'mounts', 'NNS'),
#  (u'on', 'IN'),
#  (u'high', 'JJ'),
#  (u'dark', 'NN'),
#  (u'over', 'IN'),
#  (u'the', 'DT'),
#  (u'rooftops', 'NNS'),
#  (u'.', '.')]

# %%
from wordnik.swagger import ApiClient
from wordnik.WordApi import WordApi
apiUrl = 'http://api.wordnik.com/v4'
apiKey = 'de028afe6c335a869300008d89e0abefda56bbb27e85579d0'
client = ApiClient(apiKey, apiUrl)
wordApi = WordApi(client)

# %%
antonyms = wordApi.getRelatedWords("drives", relationshipTypes="antonym")
context = wordApi.getRelatedWords("drives", relationshipTypes="same-context")

related_words = set()
if antonyms:
    related_words.update([word.lower() for word in antonyms[0].words])
if context:
    related_words.update([word.lower() for word in context[0].words])
related_words
# Out:
# {u'computer',
#  u'device',
#  u'driver',
#  u'engine',
#  u'machine',
#  u'move',
#  u'ride',
#  u'speed',
#  u'train',
#  u'walk'}

# %% [markdown]
# # Markov!

# %%
from collections import defaultdict
import nltk 
from nltk.util import ngrams

import re

class MarkovChain(object):
    def __init__(self, n=2, divider_token='^'):
        self.n = n
        self.transition_probabilities = defaultdict(nltk.FreqDist)
        self.divider_token = divider_token
        
    def tokenize_sentence(self, sentence):
        sentence = sentence.lower()
        sentence = (self.divider_token + ' ') * self.n + sentence + (' ' + self.divider_token) * self.n
        word_tokenized = nltk.tokenize.word_tokenize(sentence)
        return list(ngrams(word_tokenized,  self.n))
    
    def train_sentence(self, sentence):
        tokenized = self.tokenize_sentence(sentence)
        num_tokens = len(tokenized)
        for i, token in enumerate(tokenized):
            if i < num_tokens - 1:
                next_token = tokenized[i + 1]
                self.transition_probabilities[token][next_token[self.n - 1:]] += 1
    
    def _get_sentence_starter(self):
        return self.n * (self.divider_token,)
    
    def get_next(self, current, weighted_by_probability=False):
        
        next_freq = self.transition_probabilities[current]
        
        if weighted_by_probability:
            prob_dist = nltk.MLEProbDist(next_freq)
            return prob_dist.generate()
        else:
            prob_dist = nltk.UniformProbDist(next_freq)
            return prob_dist.generate()
    
    def _clean_sentence(self, generated_sentence):
        cleaned = ' '.join(generated_sentence[self.n:-self.n])
        cleaned = cleaned.capitalize()
        cleaned = re.sub(' (\W)', r'\1', cleaned) # Remove space before punct
        return cleaned
    
    def generate_sentence(self, max_words=100):

        sentence = current = start = self._get_sentence_starter()
        count = 0
        while True:
            count += 1

            next_token = self.get_next(current)
            sentence = sentence + next_token
            current = sentence[-self.n:]            
            if current == start or count > max_words:
                break
        return self._clean_sentence(sentence)

# %%
chain = MarkovChain(n=3)
for sentence in riddle_sentences:
    chain.train_sentence(sentence)

    

def get_unique_sentence(chain, real_sentences):
    s = chain.generate_sentence()
    while s.lower() in real_sentences:
        s = chain.generate_sentence()
    return s


def get_tweet(riddle_sentences, n=3):
    chain = MarkovChain(n=n)
    for sentence in riddle_sentences:
        chain.train_sentence(sentence)

    cleaned_riddles = map(lambda x: x.lower().encode('utf-8').replace('\xa0', '').sub(' +', , 
                          riddle_sentences)
    real_sentences = set()

    tweet = ''

    while True:
        next_sentence = get_unique_sentence(chain, real_sentences)
        if len(next_sentence) > 140:
            continue
        if len(tweet) > 0 and len(tweet) + len(next_sentence) > 139:
            break
        tweet = tweet + next_sentence + ' '

    return tweet[:-1]
get_tweet(riddle_sentences)
# Out:
# u'Whenever i am bent and there flies from my bosom the poisonous dart i am all eager to drive afar off the deadly bale.'

# %%
get_tweet(riddle_sentences)
# Out:
# u'Many remember what goes through my mouth. Long is it to relate how its way of life will go thereafter fate\u2019s crooked ways.'

# %%
re.sub(' (\W)', r'\1', s)
# Out:
# u'Beautifully blooms; i have on my head, bites my bare body, breaks my sprouts.'

# %%
s
# Out:
# u'S i l y   o n e   t e a r s   a s u n d e r   w h a t   w a s   n e v e r   u n i t e d , \n o u r   s o n g   t o g e t h e'

# %%
map(lambda x: x.lower(), riddle_sentences)
# Out:
# [u'what good man is \xa0\xa0\xa0 so learned and so clever\nthat he can say who drives me \xa0\xa0\xa0 forth on my way?',
#  u'when i rise up strong \xa0\xa0\xa0 at times furious,\ni thunder mightily \xa0\xa0\xa0 and again with havoc\ni sweep over the land, \xa0\xa0\xa0 burn the great hall,\nravage the buildings.',
#  u'smoke mounts on high\ndark over the rooftops.',
#  u'clamor is everywhere,\nsudden death among men.',
#  u'when i shake the forest,\nthe trees proud in their fruit, \xa0\xa0\xa0 i fell the boles.',
#  u'with my roof of water, \xa0\xa0\xa0 by the powers above\ni am driven far and wide \xa0\xa0\xa0 on my avenging path.',
#  u'i bear on my back \xa0\xa0\xa0 what once covered the forms\nof the earth-dwellers, \xa0\xa0\xa0 their body and soul\ntogether in the waters.',
#  u'say what covers me\nor what i am called \xa0\xa0\xa0 who bear this burden.',
#  u'i know a noble guest, \xa0\xa0\xa0 dear to princes,\nwhom grim hunger \xa0\xa0\xa0 cannot harm,\nnor hot thirst, \xa0\xa0\xa0 nor age nor illness.',
#  u'if kindly the servant \xa0\xa0\xa0 always tend him,\nhe who must go \xa0\xa0\xa0 along on the journey;\nsafe and certain \xa0\xa0\xa0 they will find at home\nfood and joy \xa0\xa0\xa0 and countless kin;\nbut sorrow if the servant \xa0\xa0\xa0 obeys his lord badly,\nhis master on their journey; \xa0\xa0\xa0 nor will brother fear brother\nwhen unharmed they leave quickly \xa0\xa0\xa0 the bosom of their kin,\nmother and sister.',
#  u'let whoever will\nwith fitting words \xa0\xa0\xa0 name the guest or the servant\ni speak of here.',
#  u'eternal is the creator \xa0\xa0\xa0 who controls this earth now\non its foundations \u2026 \xa0\xa0\xa0 [and] holds the world.',
#  u'strong is the ruler \xa0\xa0\xa0 and king by right,\nmighty over all.',
#  u'the earth and the heavens\nhe holds and wields \xa0\xa0\xa0 as he encircles them about.',
#  u'me he wondrously \xa0\xa0\xa0 made at the beginning\nwhen at the first \xa0\xa0\xa0 he established this universe.',
#  u'he bade me to live \xa0\xa0\xa0 long unsleeping\nthat i slumber not \xa0\xa0\xa0 forever after.',
#  u'and me suddenly \xa0\xa0\xa0 sleep overcomes;\nboth my eyes \xa0\xa0\xa0 are quickly closed.',
#  u'all this world \xa0\xa0\xa0 the mighty lord\nmoves with mastery \xa0\xa0\xa0 in all its parts;\nso that i at the world \xa0\xa0\xa0 of the mighty ruler\nall this universe \xa0\xa0\xa0 encircle about.',
#  u'i am so timid \xa0\xa0\xa0 that a fleeting phantom\nterribly can \xa0\xa0\xa0 fill me with fright;\nand i am everywhere \xa0\xa0\xa0 bolder than a boar\nwhen swollen with fury \xa0\xa0\xa0 it stands at bay.',
#  u'no banner-bearer \xa0\xa0\xa0 can overcome me\nthroughout the world \xa0\xa0\xa0 save god alone\nwho holds and rules \xa0\xa0\xa0 this high heaven.',
#  u'my fragrance is stronger \xa0\xa0\xa0 .',
#  u'than any incense \xa0\xa0\xa0 or any rose\nin the field of earth \xa0\xa0\xa0 .',
#  u'beautifully blooms; \xa0\xa0\xa0 i am stronger than that.',
#  u'although the lily \xa0\xa0\xa0 is precious to men,\nand bright of blossom \xa0\xa0\xa0 i am better than it;\nthus the odor of nard \xa0\xa0\xa0 i (quite) overcome\nwith my very sweetness \xa0\xa0\xa0 ever and everywhere.',
#  u'and i am fouler \xa0\xa0\xa0 than this black fen\nthat here evilly \xa0\xa0\xa0 smells of filth.',
#  u'and i govern \xa0\xa0\xa0 under heaven\u2019s expanse\nas the beloved father \xa0\xa0\xa0 taught me at the start,\nthat i must rule \xa0\xa0\xa0 with right justice\nover thick and thin, \xa0\xa0\xa0 and everywhere hold\nthe form and feature \xa0\xa0\xa0 of every thing.',
#  u'i am brighter than heaven; \xa0\xa0\xa0 the high king bids me\nto hold and cherish \xa0\xa0\xa0 his secret treasures.',
#  u'i scan all things also \xa0\xa0\xa0 under the earth,\nthe dirty dens \xa0\xa0\xa0 of evil spirits.',
#  u'i am very much older \xa0\xa0\xa0 than this universe\nor this middle-world \xa0\xa0\xa0 could ever be.',
#  u'i was yesterday born, \xa0\xa0\xa0 a child begotten\nto the glory of man, \xa0\xa0\xa0 from my mother\u2019s womb.',
#  u'fairer i am \xa0\xa0\xa0 than ornaments of gold,\nalthough they be covered \xa0\xa0\xa0 with delicate work.',
#  u'i am filthier too \xa0\xa0\xa0 than this foul wood\nor this seaweed \xa0\xa0\xa0 that lies cast up here.',
#  u'i am wider than the world \xa0\xa0\xa0 any and everywhere\nand extend farther \xa0\xa0\xa0 than this green meadow.',
#  u'a hand can seize me \xa0\xa0\xa0 and three fingers\ncan easily embrace me \xa0\xa0\xa0 all round about.',
#  u'i am harder and colder \xa0\xa0\xa0 than the hard frost;\nthe grim rime \xa0\xa0\xa0 when it comes on the ground.',
#  u'[i am] hotter than vulcan\u2019s \xa0\xa0\xa0 up-ascending\nfire and brightly \xa0\xa0\xa0 shining flame.',
#  u'i am on the palate \xa0\xa0\xa0 of men sweeter\nthan the honeycomb \xa0\xa0\xa0 when filled with honey.',
#  u'just so am i bitterer \xa0\xa0\xa0 than wormwood is\nthat darkly stands \xa0\xa0\xa0 here in the forest.',
#  u'feed i can \xa0\xa0\xa0 even more mightily\nand eat just as much \xa0\xa0\xa0 as an old giant,\nand i always can live \xa0\xa0\xa0 a happy life\nthough i see no food \xa0\xa0\xa0 my whole life long.',
#  u'i can fly more boldly \xa0\xa0\xa0 than the pernex[2] can\nor eagle or hawk \xa0\xa0\xa0 ever could.',
#  u'there is no zephyrus, \xa0\xa0\xa0 that rapid wind,\nthat can anywhere \xa0\xa0\xa0 so boldly move.',
#  u'the snail is swifter than i, \xa0\xa0\xa0 the earthworm faster,\nthe swamp frog \xa0\xa0\xa0 more active in movement\nand the offspring of dung \xa0\xa0\xa0 is quicker in stirring,\nwhich we call \u201cbeetle,\u201d \xa0\xa0\xa0 when we give it a name.',
#  u'i am heavier far \xa0\xa0\xa0 than the gray stone\nor a lump of lead \xa0\xa0\xa0 which is not small.',
#  u'i am much lighter \xa0\xa0\xa0 than this little bug\nwhich walks on the water \xa0\xa0\xa0 with dry feet;\nthan the flint i am harder \xa0\xa0\xa0 which drives this fire\nfrom this strong, \xa0\xa0\xa0 this hard, steel.',
#  u'i am softer far \xa0\xa0\xa0 than the downy feather\nthat here in the wind \xa0\xa0\xa0 flutters on the air.',
#  u'i am everywhere \xa0\xa0\xa0 broader than all the earth\nand farther extend \xa0\xa0\xa0 than this green meadow.',
#  u'[3]\ni encircle \u2026 \xa0\xa0\xa0 all round about\nwondrously woven \xa0\xa0\xa0 with wonderful skill.',
#  u'under me there is \xa0\xa0\xa0 no other\nmore powerful wight \xa0\xa0\xa0 among living things.',
#  u'i am above \xa0\xa0\xa0 the creatures all\nwhich our lord \xa0\xa0\xa0 did create\nwho can me alone \xa0\xa0\xa0 by his eternal power\nrestrain by force \xa0\xa0\xa0 from exceeding my bounds.',
#  u'i am greater and stronger \xa0\xa0\xa0 than the large whale\nwhich looks on the bottom \xa0\xa0\xa0 of the sea-deeps\nwith dim vision; \xa0\xa0\xa0 i am mightier than he\neven as i am less \xa0\xa0\xa0 in my own strength\nthan the handworm which \xa0\xa0\xa0 the sons of men\nin skilful manner \xa0\xa0\xa0 dig out with a knife.',
#  u'i have on my head \xa0\xa0\xa0 no white locks,\ncunningly curled, \xa0\xa0\xa0 but i am quite bald;\nnor could i enjoy \xa0\xa0\xa0 eyelids or eyebrows.',
#  u'but me the creator \xa0\xa0\xa0 deprived of them all.',
#  u'now wondrously \xa0\xa0\xa0 grow on my head\nso that they may \xa0\xa0\xa0 shine on my shoulders,\nfull wondrously, \xa0\xa0\xa0 curly locks.',
#  u'i am bigger and fatter \xa0\xa0\xa0 than the masty swine,\nthe grunting boar \xa0\xa0\xa0 in the beech forest\nthat dark and rooting \xa0\xa0\xa0 happy lives,\nso that he \u2026 \xa0\xa0\xa0 .',
#  u'i am greater \xa0\xa0\xa0 than all this world is,\nless than the handworm, \xa0\xa0\xa0 brighter than the moon,\nswifter than the sun.',
#  u'all seas and waters\nare in my embraces, \xa0\xa0\xa0 and the bosom of earth\nand the green fields.',
#  u'i reach to the ground,\ni descend below hell, \xa0\xa0\xa0 i rise above the heavens,\nthe land of glory.',
#  u'i extend far over\nthe home of angels.',
#  u'i fill the earth,\nthe whole wide world \xa0\xa0\xa0 and the ocean currents,\nall by myself.',
#  u'say what my name is.',
#  u'i saw in the hall \xa0\xa0\xa0 where heroes drank\na thing of four kinds \xa0\xa0\xa0 borne in thither.',
#  u'it was of splendid wood, \xa0\xa0\xa0 and twisted gold,\nskilfully wound, \xa0\xa0\xa0 and part of it silver;\nand the sign of the road \xa0\xa0\xa0 of him who raised us\nstep by step \xa0\xa0\xa0 up to heaven\nbefore he stormed \xa0\xa0\xa0 the castle of hell\u2019s people.',
#  u'i can readily report \xa0\xa0\xa0 on the excellence of the wood:\nthere was maple and oak \xa0\xa0\xa0 and tough yew\nand the dark holly.',
#  u'they are all together\na help to good men.',
#  u'one name they have:\nwolf-head tree, \xa0\xa0\xa0 that often afforded\na weapon for its lord, \xa0\xa0\xa0 a treasure in the hall,\na gold-hilted sword.',
#  u'now show me the answer\nof this my song, \xa0\xa0\xa0 whoever may presume\nto say in words \xa0\xa0\xa0 how the wood is called.',
#  u'i am an active flame; \xa0\xa0\xa0 i sport with the wind,\nenwound with wonder, \xa0\xa0\xa0 enwrapped by the storm,\neager on my way, \xa0\xa0\xa0 troubled by fire,\na blooming grove, \xa0\xa0\xa0 a burning flame.',
#  u'friends often pass me \xa0\xa0\xa0 from hand to hand\nso that men and women \xa0\xa0\xa0 proudly kiss me.',
#  u'when i rise up \xa0\xa0\xa0 they bow down to me,\nmany joyfully, \xa0\xa0\xa0 where i shall add\nto the oncoming \xa0\xa0\xa0 of blessedness to men.',
#  u'i have heard of a ring \xa0\xa0\xa0 bright without tongue\nintercede for heroes.',
#  u'well it spoke\nwith strong words \xa0\xa0\xa0 though not loud.',
#  u'this treasure for men \xa0\xa0\xa0 silently said:\n\u201cheal me \xa0\xa0\xa0 helper of souls.\u201d\nmay men understand \xa0\xa0\xa0 the magic meaning\nof the speech of the red gold.',
#  u'may the wise entrust\ntheir salvation to god, \xa0\xa0\xa0 as the ring said.',
#  u'i saw in the hall \xa0\xa0\xa0 a golden ring\nwhich men beheld \xa0\xa0\xa0 with happy hearts,\nwith wise minds.',
#  u'peace and salvation\nhas god offered \xa0\xa0\xa0 to every guest\nwho turns the ring.',
#  u'a word then it spoke,\nthe ring to the gathering.',
#  u'it named the saviour\nof righteous men.',
#  u'dumb it brought\nclearly to their minds \xa0\xa0\xa0 the lord\u2019s name\nand to the sight of their eyes \xa0\xa0\xa0 if one could grasp\nthe true meaning \xa0\xa0\xa0 of the noble gold.',
#  u'the wounded lord, \xa0\xa0\xa0 do as the wounds\nof the ring had said.',
#  u'nor can to the prayer \xa0\xa0\xa0 .',
#  u'the soul of any man \xa0\xa0\xa0 unfulfilled\nseek the princely city, \xa0\xa0\xa0 the castle of heaven.',
#  u'explain how the wounds \xa0\xa0\xa0 of this splendid ring\nspoke to mortals \xa0\xa0\xa0 when there in the hall\nit was turned and revolved \xa0\xa0\xa0 in the hands of the proud.',
#  u'christ, the commander, \xa0\xa0\xa0 the true lord of victories,\nordained me for conflict.',
#  u'i burn the living,\nunnumbered mortals, \xa0\xa0\xa0 over all the earth.',
#  u'i afflict them with pain, \xa0\xa0\xa0 yet never i touch them,\nwhenever my lord \xa0\xa0\xa0 bids me to battle.',
#  u'sometimes i gladden \xa0\xa0\xa0 the minds of many;\nsometimes i comfort \xa0\xa0\xa0 those i make war on,\neven from afar.',
#  u'they feel it, nonetheless,\nthe hurt and the healing, \xa0\xa0\xa0 when now and again,\nover deep tribulation, \xa0\xa0\xa0 i better their fortunes.',
#  u'my garment is darkish.',
#  u'bright decorations,\nred and radiant, \xa0\xa0\xa0 i have on my raiment.',
#  u'i mislead the stupid \xa0\xa0\xa0 and stimulate the foolish\ntoward unwise ways.',
#  u'others i restrain\nfrom profitable paths.',
#  u'but i know not at all\nthat they, maddened, \xa0\xa0\xa0 robbed of their senses,\nastray in their actions \xa0\xa0\xa0 \u2014that they praise to all men\nmy wicked ways.',
#  u'woe to them then\nwhen the most high holds out \xa0\xa0\xa0 his dearest of gifts\nif they do not desist \xa0\xa0\xa0 first from their folly.',
#  u'over the hillsides \xa0\xa0\xa0 this air upholds\nbright little creatures, \xa0\xa0\xa0 swarthy and dark-clad;\nbold of song, \xa0\xa0\xa0 they fare in flocks\nand loudly chirp.',
#  u'they tread the headlands,\nsometimes men\u2019s houses.',
#  u'they name themselves.',
#  u'sometimes i set forth \xa0\xa0\xa0 \u2014when none would expect it\u2014\nunder turbulent waves, \xa0\xa0\xa0 seeking the depths,\nthe floor of ocean.',
#  u'the sea is aroused,\n.',
#  u'foam is tossed up;\nthe home of whales \xa0\xa0\xa0 roars and rages.',
#  u'streams lash the shore, \xa0\xa0\xa0 violently dash\nup the steep strand \xa0\xa0\xa0 with sand and shingle\nand seaweed, when surging \xa0\xa0\xa0 i struggle and strive\nbeneath the sea currents, \xa0\xa0\xa0 stir up the bottom,\nthe broad sea deeps.',
#  u'nor can i escape\nfrom the sea\u2019s surface \xa0\xa0\xa0 until he permits\nwho guides all my ways.',
#  u'o wise man, say,\nwho is it drew me \xa0\xa0\xa0 from the sea\u2019s embraces\nwhen the surges again \xa0\xa0\xa0 are stilled and quiet\nand calm the waves \xa0\xa0\xa0 which covered me first.',
#  u'sometimes my lord \xa0\xa0\xa0 constrains me close\nand forces me under \xa0\xa0\xa0 the broad bosom\nof the fertile fields \xa0\xa0\xa0 and holds me there,\ndrives me into darkness, \xa0\xa0\xa0 where hard on my back\nthe earth sits heavy.',
#  u'there is no escape\nfrom all that torment; \xa0\xa0\xa0 but the houses of heroes,\ntheir gabled halls, \xa0\xa0\xa0 i cause to tremble\nand shake the walls \xa0\xa0\xa0 of the dwellings of men,\nhigh over their heads.',
#  u'the air seems still\nin the skies above \xa0\xa0\xa0 and the waters quiet\u2014\nuntil from confinement \xa0\xa0\xa0 upwards i thrust,\neven as he commands \xa0\xa0\xa0 who laid at the beginning\nmy fetters upon me.',
#  u'i can never be free\nfrom the power that points \xa0\xa0\xa0 the path i follow.',
#  u'sometimes from above \xa0\xa0\xa0 i rouse the surges,\nstir up the waters \xa0\xa0\xa0 and drive to the shore\nthe flint-gray flood.',
#  u'foaming the waves\nfight with the wall.',
#  u'dim stands up\nthe dune over the deep; \xa0\xa0\xa0 dark behind it\nblended with the sea \xa0\xa0\xa0 comes another surge.',
#  u'together they meet \xa0\xa0\xa0 by the sea-mark there\nby the high ridges.',
#  u'loud is the wooden ship,\nthe noise of the sailors.',
#  u'calmly await\nthe steep stone cliffs \xa0\xa0\xa0 the battle of waters,\nthe clashing waves, \xa0\xa0\xa0 when high the violence\ncrowds on the headlands.',
#  u'there must the keel\nfind bitter battle, \xa0\xa0\xa0 if the sea lifts it\nwith all its men \xa0\xa0\xa0 in that terrible hour;\ntill out of control, \xa0\xa0\xa0 robbed of its life,\nit rides through the foam \xa0\xa0\xa0 on the back of the waves.',
#  u'then will be panic there, \xa0\xa0\xa0 manifest to mortals;\n.',
#  u'but i must obey,\nstrong on my fierce way.',
#  u'who will still that?',
#  u'sometimes i rush \xa0\xa0\xa0 through the wan wet clouds\nthat ride on my back, \xa0\xa0\xa0 scatter them wide\nwith their streaming water.',
#  u'sometimes i allow them\nto glide together.',
#  u'great is the din,\nuproar over houses, \xa0\xa0\xa0 and loudest of crashes,\nwhen fiercely comes \xa0\xa0\xa0 cloud against cloud\nlike sword against sword.',
#  u'darkling spirits,\nswift over mortals, \xa0\xa0\xa0 sweat with fire,\nwith gleaming flame \xa0\xa0\xa0 and fearful noises.',
#  u'above mankind \xa0\xa0\xa0 with dreadful din\nthey fare fighting; \xa0\xa0\xa0 they let fall then\nswart rattling streams \xa0\xa0\xa0 from out their bosom,\nwater from within.',
#  u'fighting moves on\nthe terrible host; \xa0\xa0\xa0 panic arises,\na mighty fear \xa0\xa0\xa0 in the hearts of mankind;\nhorror in towns \xa0\xa0\xa0 when gleaming shoots\nthe gliding demon \xa0\xa0\xa0 with sharp weapons.',
#  u'he is dull who dreads not \xa0\xa0\xa0 these arrows of death;\nhe dies nonetheless \xa0\xa0\xa0 if the true lord\ndown through the rain, \xa0\xa0\xa0 straight from above\nlets fly the darts \xa0\xa0\xa0 of the fiery storm,\nits swift arrows.',
#  u'few escape this\nwho are reached by the darts \xa0\xa0\xa0 of the hostile rain.',
#  u'i stand in the van \xa0\xa0\xa0 of this battlefront\nwhen on i press \xa0\xa0\xa0 the column of cloud,\npush through the strife \xa0\xa0\xa0 in masterful might\non the breast of the burns.',
#  u'crowding in battle\nthe high storm bursts.',
#  u'then down i bend\nunder the helm of the sky \xa0\xa0\xa0 close to the ground,\nbearing on my back \xa0\xa0\xa0 the burden i carry\nby the command of him, \xa0\xa0\xa0 the all-powerful lord.',
#  u'thus a mighty servant \xa0\xa0\xa0 i do battle by turns\u2014\nsometimes under ground; \xa0\xa0\xa0 sometimes i must deep\nundermine the waves; \xa0\xa0\xa0 sometimes from on high\ni arouse the waters, \xa0\xa0\xa0 or rising aloft\nstir up the clouds.',
#  u'widely i pass,\nswift and violent.',
#  u'tell me my name,\nor who lifts and drives me, \xa0\xa0\xa0 when i may not rest,\nor who it is steadies me \xa0\xa0\xa0 when i become still.',
#  u'in those first days \xa0\xa0\xa0 my father and mother\nleft me for dead: \xa0\xa0\xa0 there was no life yet,\nno life within me.',
#  u'then a kindly kinswoman\nfaithfully covered me \xa0\xa0\xa0 with her own clothing,\nheld me and cherished, \xa0\xa0\xa0 kept me warmly,\neven as gently \xa0\xa0\xa0 as her own children\u2014\nuntil beneath her, \xa0\xa0\xa0 as my destiny willed,\ni waxed into life \xa0\xa0\xa0 with my alien fellows.',
#  u'my friend and protector \xa0\xa0\xa0 nourished me then\ntill i grew and grew able \xa0\xa0\xa0 to go forth by myself.',
#  u'because of this now \xa0\xa0\xa0 her own dear children,\nsons and daughters, \xa0\xa0\xa0 were fewer, alas.',
#  u'silent is my garment \xa0\xa0\xa0 when i tread the earth\nor dwell in the towns \xa0\xa0\xa0 or stir the waters.',
#  u'sometimes my trappings \xa0\xa0\xa0 lift me up over\nthe habitations of heroes \xa0\xa0\xa0 and this high air,\nand the might of the welkin \xa0\xa0\xa0 bears me afar\nabove mankind.',
#  u'then my adornments\nresound in song \xa0\xa0\xa0 and sing aloud\nwith clear melody \xa0\xa0\xa0 \u2014when i do not rest\non land or water, \xa0\xa0\xa0 a moving spirit.',
#  u'i speak through my mouth \xa0\xa0\xa0 with many voices.',
#  u'skilfully i sing \xa0\xa0\xa0 with many modulations,\nloud and strong, with various tunes.',
#  u'i sing as i must, \xa0\xa0\xa0 unhampered, unhindered.',
#  u'i am the nighttime \xa0\xa0\xa0 songster of old.',
#  u'i bring joy to the men \xa0\xa0\xa0 who dwell in the towns.',
#  u'when i sing out \xa0\xa0\xa0 with my flexible tones\nthey sit at home silent.',
#  u'tell me my name\nwho brightly imitate \xa0\xa0\xa0 professional singers\nand loudly foretell \xa0\xa0\xa0 many welcome tidings.',
#  u'my beak was close fettered, \xa0\xa0\xa0 the currents of ocean,\nrunning cold beneath me.',
#  u'there i grew in the sea,\nmy body close \xa0\xa0\xa0 to the moving wood.',
#  u'i was all alive \xa0\xa0\xa0 when i came from the water,\nclad all in black, \xa0\xa0\xa0 but a part of me white.',
#  u'when living, the air \xa0\xa0\xa0 lifted me up,\nthe wind from the wave, \xa0\xa0\xa0 and bore me afar,\nup over the seal\u2019s bath.',
#  u'tell me my name.',
#  u'i move on my feet, \xa0\xa0\xa0 i break up the ground,\nthe green meadows, \xa0\xa0\xa0 as long as i live.',
#  u'if life leaves me \xa0\xa0\xa0 i then bind fast\nthe swarthy welsh, \xa0\xa0\xa0 and sometimes better men.',
#  u'sometimes i give drink \xa0\xa0\xa0 to a strong man\nfrom out of my bosom.',
#  u'sometimes the stately dame\ntreads me underfoot.',
#  u'sometimes the welsh girl,\ndark-haired slave \xa0\xa0\xa0 brought from afar,\nstupid and drunk, \xa0\xa0\xa0 on dark nights\nlifts me and presses me, \xa0\xa0\xa0 soaks me in water,\nwarms me sometimes \xa0\xa0\xa0 kindly by the fire,\nher wanton hands \xa0\xa0\xa0 thrust in my bosom;\nturning often \xa0\xa0\xa0 sweeps through the dark.',
#  u'say what my name is \xa0\xa0\xa0 who living ravage\nthe land, and dead \xa0\xa0\xa0 am of service to men.',
#  u'i was little \u2026 \xa0\xa0\xa0 \u2026 my sister fed me.',
#  u'\u2026\noften i tugged \xa0\xa0\xa0 at four dear brothers,\neach one gave me \xa0\xa0\xa0 daily to drink,\nthrough a hole freely.',
#  u'i throve happily\nuntil i was older \xa0\xa0\xa0 and left all that\nto the swarthy herdsman.',
#  u'i traveled farther\nto the welsh marches, \xa0\xa0\xa0 traversed the moors,\nbound under a beam.',
#  u'i had a ring on my neck,\nsuffered woes on my way, \xa0\xa0\xa0 was forced to perform\nmy share of labors.',
#  u'often the goad hurt me\nsorely on my sides.',
#  u'but i was silent,\nnever spoke out \xa0\xa0\xa0 to any man,\nif ever the pricks \xa0\xa0\xa0 were painful to me.',
#  u'i saw the creature, \xa0\xa0\xa0 of the arms-bearing kind,\ngreedy for youth\u2019s joys.',
#  u'as its due it let\nfour nourishing fountains, \xa0\xa0\xa0 brightly shining,\nshoot forth noisily, \xa0\xa0\xa0 as is right and proper.',
#  u'then spake a man, \xa0\xa0\xa0 who said to me:\n\u201cthe creature, if it lives, \xa0\xa0\xa0 will break up the hillside;\nif rent apart, \xa0\xa0\xa0 will bind the living.\u201d',
#  u'i saw a woman \xa0\xa0\xa0 sitting alone.',
#  u'i saw them, all ten, \xa0\xa0\xa0 treading the turf,\nthe six brothers \xa0\xa0\xa0 and their sisters too,\nliving and lively.',
#  u'their skins hung plainly,\nvisibly manifest, \xa0\xa0\xa0 on the wall of the house,\neach and every one; \xa0\xa0\xa0 nor was any the worse,\nnor side the sorer, \xa0\xa0\xa0 though thus they must,\ndespoiled of their raiment, \xa0\xa0\xa0 roused by the power\nof heaven\u2019s lord, \xa0\xa0\xa0 tear with their mouths\nthe gray-green leaves.',
#  u'their garment is renewed;\nhaving now come forth \xa0\xa0\xa0 they leave their coverings\nlying behind them \xa0\xa0\xa0 as they tread the ground.',
#  u'my neck is white, \xa0\xa0\xa0 my head is tawny\nand so are my sides.',
#  u'i am swift in my stride.',
#  u'i bear weapons of battle.',
#  u'on my back there is hair\nand the same on my cheeks.',
#  u'over my eyes\ntwo ears stand up.',
#  u'i walk on my toes\nin the green grass.',
#  u'my doom is certain\nif anyone finds me, \xa0\xa0\xa0 if a slaughterous fighter\nfinds me hidden \xa0\xa0\xa0 where i make my home,\nbold with my bairns.',
#  u'and there i abide\nwith my little family \xa0\xa0\xa0 when the stranger comes\nto my very doors.',
#  u'death is their doom.',
#  u'i must carry them off, \xa0\xa0\xa0 save them by flight\nwith fear in my heart \xa0\xa0\xa0 away from my home.',
#  u'if he crowds me hard, \xa0\xa0\xa0 moving on his belly,\ni dare not abide \xa0\xa0\xa0 that fierce one in my burrow\n(that would be surely \xa0\xa0\xa0 not a good counsel)\nbut bravely i must \xa0\xa0\xa0 with both hands and feet\ncreate a path \xa0\xa0\xa0 through the high hill.',
#  u'easily i can save them, \xa0\xa0\xa0 my beloved kin,\nif i can bring my household \xa0\xa0\xa0 by a secret way\nthrough the hollow hill; \xa0\xa0\xa0 for there i need fear\nnever a whit \xa0\xa0\xa0 the murderous whelp.',
#  u'if the hateful foe \xa0\xa0\xa0 follows me hard\nthrough the narrow track \xa0\xa0\xa0 he shall have no lack\nof the clash of battle \xa0\xa0\xa0 when we meet in the burrow;\nwhen i get to the top \xa0\xa0\xa0 of the hill and turn on him\nwith weapons of war, \xa0\xa0\xa0 whom i formerly fled from.',
#  u'i saw a being \xa0\xa0\xa0 in wondrous wise\nhold its plunder \xa0\xa0\xa0 between its horns,\na vessel of light, \xa0\xa0\xa0 of shining beauty,\nbringing it home, \xa0\xa0\xa0 a spoil of battle.',
#  u'it wished to build \xa0\xa0\xa0 a bower in the burg\nand cunningly place it \xa0\xa0\xa0 \u2014if so might be.',
#  u'then a wondrous being \xa0\xa0\xa0 came over the roof,\nknown to all children \xa0\xa0\xa0 of mortal men,\nrecovered the spoil \xa0\xa0\xa0 and then brought back\nthe unwilling exile.',
#  u'westward it went,\nhurrying home \xa0\xa0\xa0 after the battle.',
#  u'dust rose to the skies; \xa0\xa0\xa0 dew fell on the ground;\nnight departed \xa0\xa0\xa0 and none thereafter\nknew its way, \xa0\xa0\xa0 whither it went.',
#  u'the sea fed me; \xa0\xa0\xa0 the water-helm was over me,\nand waves covered me, \xa0\xa0\xa0 close to the ground.',
#  u'often toward the water\ni opened my mouth.',
#  u'now people will\neat my meat.',
#  u'they want not my skin.',
#  u'when they rip my hide \xa0\xa0\xa0 with the point of a knife\n.',
#  u'then they eat me uncooked.',
#  u'i saw a thing \xa0\xa0\xa0 in the dwellings of men\nthat feeds the cattle; \xa0\xa0\xa0 has many teeth.',
#  u'the beak is useful to it; \xa0\xa0\xa0 it goes downwards,\nravages faithfully; \xa0\xa0\xa0 pulls homewards;\nhunts along walls; \xa0\xa0\xa0 reaches for roots.',
#  u'always it finds them, \xa0\xa0\xa0 those which are not fast;\nlets them, the beautiful, \xa0\xa0\xa0 when they are fast,\nstand in quiet \xa0\xa0\xa0 in their proper places,\nbrightly shining, \xa0\xa0\xa0 growing, blooming.',
#  u'my beak is downward \xa0\xa0\xa0 and low i move\nand dig in the ground.',
#  u'the hoar foe of the forest\ndirects my movements; \xa0\xa0\xa0 and so my master\ngoes bent over, \xa0\xa0\xa0 the guide at my tail,\ndrives across the field, \xa0\xa0\xa0 pushes me and crowds me,\nand sows in my swath.',
#  u'i go sniffing along,\nbrought from the woodland, \xa0\xa0\xa0 stoutly fastened,\nborne on a wagon.',
#  u'i have many strange ways.',
#  u'i leave green on one side \xa0\xa0\xa0 and black on the other.',
#  u'driven through my back \xa0\xa0\xa0 there hangs beneath\na well-sharpened point; \xa0\xa0\xa0 on my head another,\nfirm and forward-moving.',
#  u'what i tear with my teeth\nfalls to the side, \xa0\xa0\xa0 if he serves me well,\nmy lord who behind me \xa0\xa0\xa0 heeds me and guides me.',
#  u'my head is \xa0\xa0\xa0 forged with the hammer,\nhurt with sharp tools, \xa0\xa0\xa0 smoothed by files.',
#  u'i take in my mouth \xa0\xa0\xa0 what is set before me\nwhen girded with rings \xa0\xa0\xa0 i am forced to strike,\nhard against hard, \xa0\xa0\xa0 pierced from behind,\nmust draw forth \xa0\xa0\xa0 what protects at midnight\nthe heart\u2019s delight \xa0\xa0\xa0 of my own lord.',
#  u'sometimes i turn \xa0\xa0\xa0 backwards my beak,\nwhen, protector of treasure, \xa0\xa0\xa0 my lord wishes\nto hold the leavings \xa0\xa0\xa0 of those he had driven\nfrom life by battle-craft \xa0\xa0\xa0 for his own desire.',
#  u'i know a thing \xa0\xa0\xa0 with a single foot\ndoing deeds of might.',
#  u'it travels not\nnor rides much, \xa0\xa0\xa0 nor can it fly\nthrough the clear air; \xa0\xa0\xa0 nor does ship carry it,\na boat with nailed planks.',
#  u'it is nevertheless\nuseful to its master \xa0\xa0\xa0 at many times.',
#  u'it has a heavy tail \xa0\xa0\xa0 and a small head\nand a long tongue.',
#  u'it has no tooth;\npart is of iron.',
#  u'it goes through a hollow.',
#  u'it swallows no water, \xa0\xa0\xa0 it eats nothing,\nit desires no fodder.',
#  u'often notwithstanding\nit bears water aloft.',
#  u'it boasts not of life\nor of gifts from its chief.',
#  u'it obeys nonetheless\nits master\u2019s word.',
#  u'in its name there are\nthree real runes.',
#  u'r\u0101d is the first.',
#  u'bound with rings \xa0\xa0\xa0 i must readily obey\nfrom time to time \xa0\xa0\xa0 my servant and master\nand break my rest, \xa0\xa0\xa0 make noisily known\nthat he gave me a band \xa0\xa0\xa0 to put on my neck.',
#  u'often a man or a woman \xa0\xa0\xa0 has come to greet me,\nwhen weary with sleep, \xa0\xa0\xa0 wintry-cold, i answer him:\n(their hearts were angry): \xa0\xa0\xa0 \u201ca warm limb\nsometimes bursts \xa0\xa0\xa0 the bound ring.\u201d\nnonetheless it is pleasant \xa0\xa0\xa0 to him, my servant,\na half-witted man, \xa0\xa0\xa0 and to me the same,\nif one knows aught \xa0\xa0\xa0 and can then with words\nriddle my riddle \xa0\xa0\xa0 successfully.',
#  u'i have a puffed-out breast \xa0\xa0\xa0 and a swollen neck;\ni have a head \xa0\xa0\xa0 and a tall tail;\ni have eyes and ears \xa0\xa0\xa0 and a single foot,\na rough hard bill \xa0\xa0\xa0 and a long neck\nand two sides; \xa0\xa0\xa0 hollow in the middle.',
#  u'my home is over men.',
#  u'i suffer much\nwhenever he moves me \xa0\xa0\xa0 who stirs the forest,\nand rains and hard hail \xa0\xa0\xa0 beat on me as i stand,\nand frost freezes \xa0\xa0\xa0 and snow falls\non me, hollow-bellied \xa0\xa0\xa0 .',
#  u'i was in there \xa0\xa0\xa0 where i saw something,\na thing of wood, \xa0\xa0\xa0 wound a striving thing,\nthe moving beam \xa0\xa0\xa0 \u2014it received battle wounds,\ndeep injuries; \xa0\xa0\xa0 spears caused the hurts\nof this thing; \xa0\xa0\xa0 and the wood was fast bound\ncunningly.',
#  u'one of its feet\nwas stable, fixed; \xa0\xa0\xa0 the other worked busily,\nplayed in the air, \xa0\xa0\xa0 sometimes near the ground.',
#  u'a tree was nearby, \xa0\xa0\xa0 that stood there hung\nwith bright leaves.',
#  u'i saw the leavings\nof the arrow-work \xa0\xa0\xa0 brought to my lord\nwhere heroes sat \xa0\xa0\xa0 over their drinks.',
#  u'i know a something \xa0\xa0\xa0 that stands firm on the ground,\ndeaf and dumb, \xa0\xa0\xa0 that by day often swallows\nfrom the servant\u2019s hand \xa0\xa0\xa0 useful gifts.',
#  u'sometimes in the towns \xa0\xa0\xa0 the dark thane,\nswarthy and dun-faced, \xa0\xa0\xa0 sends more of these\ninto its mouth, \xa0\xa0\xa0 dearer than gold,\nwhich men of rank \xa0\xa0\xa0 often desire,\nkings and queens.',
#  u'i will not now yet\nname his nature \xa0\xa0\xa0 who for use and profit\nof doughty men \xa0\xa0\xa0 makes what the dumb thing\n(that dun-faced nitwit) \xa0\xa0\xa0 first swallows up.',
#  u'i was alive but said nothing; \xa0\xa0\xa0 even so i die.',
#  u'back i came before i was.',
#  u'everyone plunders me,\nkeeps me confined, \xa0\xa0\xa0 and shears my head,\nbites my bare body, \xa0\xa0\xa0 breaks my sprouts.',
#  u'no man i bite \xa0\xa0\xa0 unless he bites me;\nmany there are \xa0\xa0\xa0 who do bite me.',
#  u'the books tell us \xa0\xa0\xa0 that this thing has been\namong mankind \xa0\xa0\xa0 through many ages\nclear and manifest.',
#  u'a special power\nit has much greater \xa0\xa0\xa0 than any men know.',
#  u'it wishes to seek \xa0\xa0\xa0 all living beings\none by one; \xa0\xa0\xa0 then goes its way;\nno second night \xa0\xa0\xa0 in the same place;\nbut homeless roves \xa0\xa0\xa0 for ever and aye,\nthe path of exile.',
#  u'it is none the poorer.',
#  u'it has neither foot nor hand, \xa0\xa0\xa0 nor touches the ground,\nnor two eyes nor mouth \xa0\xa0\xa0 nor speaks with men.',
#  u'it has no mind, \xa0\xa0\xa0 but the books say\nit is quite the poorest \xa0\xa0\xa0 of all creatures\nthat were ever begotten \xa0\xa0\xa0 according to nature.',
#  u'it has no soul nor life, \xa0\xa0\xa0 but makes its way\nfar and wide \xa0\xa0\xa0 through this wonderful world\nit has no blood, no bone, \xa0\xa0\xa0 yet gives aid and comfort\nto many men \xa0\xa0\xa0 the wide world over.',
#  u'it never reached to heaven, \xa0\xa0\xa0 it may not to hell,\nbut forever it must \xa0\xa0\xa0 live by the teachings\nof the king of glory.',
#  u'long is it to relate\nhow its way of life \xa0\xa0\xa0 will go thereafter\nfate\u2019s crooked ways.',
#  u'this is a marvelous\nthing to say: \xa0\xa0\xa0 it is all true\nthat ever with words \xa0\xa0\xa0 is told about it.',
#  u'it has no limit.',
#  u'it lives nevertheless.',
#  u'if you can straightway \xa0\xa0\xa0 rede this riddle\nwith true words, \xa0\xa0\xa0 tell what its name is.',
#  u'i saw four things \xa0\xa0\xa0 in beautiful fashion\njourneying together.',
#  u'dark were their tracks,\nthe path very black.',
#  u'swift was its moving,\nfaster than birds \xa0\xa0\xa0 it flew through the air,\ndove under the wave.',
#  u'labored unresting\nthe fighting warrior \xa0\xa0\xa0 who showed them the way,\nall of the four, \xa0\xa0\xa0 over plated gold.',
#  u'i was along the sand, \xa0\xa0\xa0 near the sea-wall,\nat the water\u2019s edge, \xa0\xa0\xa0 and firmly fixed\nin the place of my birth.',
#  u'few men there were\nwho looked upon \xa0\xa0\xa0 my home of solitude.',
#  u'but at every dawn \xa0\xa0\xa0 the dark waves held me\nin their watery embrace.',
#  u'little did i think\nthat ever i should \xa0\xa0\xa0 sooner or later\nspeak without mouth \xa0\xa0\xa0 over the mead-bench,\nexchange words.',
#  u'this is a kind of wonder,\ncurious for the minds \xa0\xa0\xa0 of such as understand not\nhow the point of a knife \xa0\xa0\xa0 and a right hand\nand a prince\u2019s thought \xa0\xa0\xa0 and the point itself\npurposely fashioned it, \xa0\xa0\xa0 that i with thee\nshould boldly declare, \xa0\xa0\xa0 for us two alone,\na spoken message, \xa0\xa0\xa0 so that no other men\nshould further grasp \xa0\xa0\xa0 the words of our speech.',
#  u'a moth ate words.',
#  u'to me it seemed\na remarkable fate, \xa0\xa0\xa0 when i learned of the marvel,\nthat the worm had swallowed \xa0\xa0\xa0 the speech of a man,\na thief in the night, \xa0\xa0\xa0 a renowned saying\nand its place itself.',
#  u'though he swallowed the word\nthe thieving stranger \xa0\xa0\xa0 was no whit the wiser.',
#  u'an enemy came \xa0\xa0\xa0 and took away my life\nand my strength also \xa0\xa0\xa0 in the word; then wetted me,\ndipped me in water; \xa0\xa0\xa0 then took me thence;\nplaced me in the sun, \xa0\xa0\xa0 where i lost all my hair.',
#  u'the knife\u2019s edge cut me\u2014 \xa0\xa0\xa0 its impurities ground away;\nfingers folded me.',
#  u'and the bird\u2019s delight\nwith swift drops \xa0\xa0\xa0 made frequent traces\nover the brown surface; \xa0\xa0\xa0 swallowed the tree-dye\nwith a measure of liquid; \xa0\xa0\xa0 traveling across me,\nleft a dark track.',
#  u'a good man covered me\nwith protecting boards, \xa0\xa0\xa0 which stretched skin over me;\nadorned me with gold.',
#  u'then the work of smiths\ndecorated me with strands \xa0\xa0\xa0 of woven wire.',
#  u'now may the ornaments \xa0\xa0\xa0 and the red dye\nand the precious possessions \xa0\xa0\xa0 everywhere honor\nthe guardian of peoples.',
#  u'it were otherwise folly.',
#  u'if the sons of men \xa0\xa0\xa0 wish to enjoy me,\nthey will be the safer \xa0\xa0\xa0 and surer of victory\nand the stronger of heart \xa0\xa0\xa0 and the happier of mind\nand the wiser of spirit.',
#  u'they will have more friends,\ndearer and closer, \xa0\xa0\xa0 truer and better,\nnobler and more devoted, \xa0\xa0\xa0 who will increase\ntheir honor and wealth, \xa0\xa0\xa0 with love and favors\nand kindnesses surround them, \xa0\xa0\xa0 and clasp them close\nwith loving embraces.',
#  u'i am a help to mortals.',
#  u'my name is a glory\nand salvation to heroes, \xa0\xa0\xa0 and myself am holy.',
#  u'beautifully made \xa0\xa0\xa0 in many ways\nis this our world, \xa0\xa0\xa0 cunningly adorned.',
#  u'i saw a strange thing \xa0\xa0\xa0 singing in a house;\nits shape was more wonderful \xa0\xa0\xa0 than aught among men.',
#  u'its beak was underneath, \xa0\xa0\xa0 its feet and hands birdlike,\nyet fly it cannot \xa0\xa0\xa0 nor walk at all.',
#  u'yet eager for movement \xa0\xa0\xa0 it starts to work\nwith various arts.',
#  u'it often goes around\nagain and again \xa0\xa0\xa0 among noble men.',
#  u'it sits at the banquet-board, \xa0\xa0\xa0 awaits its turn\ntill comes its time \xa0\xa0\xa0 to display its skill\namong those who are near.',
#  u'it partakes of nothing\nthat the men there \xa0\xa0\xa0 have for their pleasure.',
#  u'brave, eager for glory \xa0\xa0\xa0 it remains dumb,\nyet it has in its foot \xa0\xa0\xa0 beautiful sounds,\na glorious gift of song.',
#  u'wondrous it seems to me\nhow this very thing \xa0\xa0\xa0 can play with words\nthrough its foot beneath \xa0\xa0\xa0 adorned with trappings.',
#  u'it has on its neck \xa0\xa0\xa0 when it guards its treasure,\nbare, proud with rings, \xa0\xa0\xa0 its two companions,\nbrother and sister.',
#  u'it\u2019s a great thing surely\nfor a wise singer \xa0\xa0\xa0 to think what this is.',
#  u'it is a splendid thing \xa0\xa0\xa0 when one knows not its ways.',
#  u'it sings through its sides.',
#  u'its neck is curved.',
#  u'and cunningly wrought.',
#  u'it has two shoulders,\nwhich are sharp, on its back.',
#  u'it follows its fate,\nwhen it stands by the road, \xa0\xa0\xa0 so handsomely there,\ntall and bright-hued; \xa0\xa0\xa0 useful to good men.',
#  u'uuob is my name \xa0\xa0\xa0 read in reverse.',
#  u'i\u2019m a beautiful thing, \xa0\xa0\xa0 shaped for fighting.',
#  u'whenever i am bent \xa0\xa0\xa0 and there flies from my bosom\nthe poisonous dart \xa0\xa0\xa0 i am all eager\nto drive afar off \xa0\xa0\xa0 the deadly bale.',
#  u'whenever my master \xa0\xa0\xa0 who shaped me that pain\nloosens my limb \xa0\xa0\xa0 i am longer than before,\ntill i spit forth again \xa0\xa0\xa0 the death-blended bane,\nthat very fell poison \xa0\xa0\xa0 which erst i swallowed.',
#  u'this that i speak of \xa0\xa0\xa0 leaves no man easily\nif that which flies from me \xa0\xa0\xa0 should ever touch him,\nso that perforce he purchases \xa0\xa0\xa0 surely with his life\nthat fatal drink, \xa0\xa0\xa0 a full atonement.',
#  u'unstrung i obey \xa0\xa0\xa0 no man, but only\nwhen skilfully tied.',
#  u'tell me my name.',
#  u'i saw a tree \xa0\xa0\xa0 with bright branches\nstand high in a grove.',
#  u'the tree was happy,\nthe growing wood.',
#  u'water and earth\nfed it well, \xa0\xa0\xa0 till wise with time\nit met with a change: \xa0\xa0\xa0 it was deeply hurt,\ndumb with bonds, \xa0\xa0\xa0 covered with wounds,\nbut adorned in front \xa0\xa0\xa0 with dark ornaments.',
#  u'now it clears the way \xa0\xa0\xa0 for a treacherous foe\nthrough the might of its head.',
#  u'by storm they plunder\nthe hoard together.',
#  u'eager was the rear\nand active in aid \xa0\xa0\xa0 if the van met danger.',
#  u'none could venture \xa0\xa0\xa0 in difficult places.',
#  u'i grew up in a field, \xa0\xa0\xa0 lived where the earth\nand the sky fed me, \xa0\xa0\xa0 till old in years\nthey turned me aside, \xa0\xa0\xa0 those who hated me,\nfrom the way that was mine, \xa0\xa0\xa0 that i held while i lived.',
#  u'they altered my fashion, \xa0\xa0\xa0 took me from the ground\nand against my nature \xa0\xa0\xa0 made me bow at times\nto a slayer\u2019s will.',
#  u'now in my master\u2019s hand\n.',
#  u'cares for me well \xa0\xa0\xa0 carries me in battle\nwith skill by his will.',
#  u'it is widely known\nthat i among the bold \xa0\xa0\xa0 with a thief\u2019s craft\n.',
#  u'sometimes openly \xa0\xa0\xa0 against a fastness\ni break forth where \xa0\xa0\xa0 before was peace.',
#  u'swift in movement \xa0\xa0\xa0 he turns in haste\naway from that place, \xa0\xa0\xa0 the warrior who knows\nwhat are my ways.',
#  u'say what my name is.',
#  u'i am a lonely thing, \xa0\xa0\xa0 wounded with iron,\nswitten by sword, \xa0\xa0\xa0 sated with battle-work,\nweary of blades.',
#  u'often i see battle,\nfierce combat.',
#  u'i foresee no comfort,\nno help will come for me \xa0\xa0\xa0 from the heat of battle,\nuntil among men \xa0\xa0\xa0 i perish utterly;\nbut the hammered swords \xa0\xa0\xa0 will beat me and bite me,\nhard-edged and sharp, \xa0\xa0\xa0 the handiwork of smiths,\nin towns among men.',
#  u'abide i must always\nthe meeting of foes.',
#  u'never could i find\namong the leeches, \xa0\xa0\xa0 where people foregather,\nany who with herbs \xa0\xa0\xa0 would heal my wounds;\nbut the sores from the swords \xa0\xa0\xa0 are always greater\nwith mortal blows \xa0\xa0\xa0 day and night.',
#  u'a thing there is \xa0\xa0\xa0 strangely begotten,\nfurious and fierce; \xa0\xa0\xa0 runs a violent course\nrages grimly, \xa0\xa0\xa0 moves over the ground,\nis mother of many \xa0\xa0\xa0 marvelous creatures.',
#  u'moving beautifully, \xa0\xa0\xa0 it is ever striving;\nlow-lying is its close grip.',
#  u'none to another\ncan fairly with wise words \xa0\xa0\xa0 describe its features\nor say how manifold \xa0\xa0\xa0 is the multitude of its kin.',
#  u'its ancient origin \xa0\xa0\xa0 the father watched over,\nbeginning and end, \xa0\xa0\xa0 and his only son also,\nglorious child of god \xa0\xa0\xa0 .',
#  u'mighty in strength \xa0\xa0\xa0 the mother is;\nsupported marvelously, \xa0\xa0\xa0 laden with food,\nadorned with treasures, \xa0\xa0\xa0 precious to heroes;\nher might is multiplied, \xa0\xa0\xa0 strength made manifest,\nher face is honored \xa0\xa0\xa0 with happy usefulness;\na fair bright jewel \xa0\xa0\xa0 for the proud to wear;\ncleanly and bountiful; \xa0\xa0\xa0 mighty in craft.',
#  u'it is dear to the prosperous, \xa0\xa0\xa0 to the poor soothing,\ngoodly, excellent; \xa0\xa0\xa0 boldest and strongest,\ngreediest and eagerest\u2014 \xa0\xa0\xa0 treads over the ground\u2014\nof all that is grown up \xa0\xa0\xa0 underneath the sky\nand that the sons of men \xa0\xa0\xa0 ever saw with their eyes.',
#  u'so that glory weaves \xa0\xa0\xa0 the might of mortals,\nalthough wise of mind \xa0\xa0\xa0 .',
#  u'a man more knowing of heart, \xa0\xa0\xa0 a crowd of wonders.',
#  u'than earth it is harder, \xa0\xa0\xa0 than heroes older,\nthan gifts readier, \xa0\xa0\xa0 than gems dearer;\nbeautifies the world; \xa0\xa0\xa0 increases in fruits;\nblots out crime \u2026\noften casts from without \xa0\xa0\xa0 a single covering\nwondrously beautiful, \xa0\xa0\xa0 over all mankind,\nso that throughout the world \xa0\xa0\xa0 men are astonished.',
#  u'me the wet ground, \xa0\xa0\xa0 exceeding cold,\nfirst brought forth \xa0\xa0\xa0 from within itself.',
#  u'neither am i wrought \xa0\xa0\xa0 of woolen fleece\nnor of hairs, with skill; \xa0\xa0\xa0 i know it in my mind.',
#  u'i have no winding wefts \xa0\xa0\xa0 nor any warp in me;\nnor with strong rods \xa0\xa0\xa0 does the thread resound for me,\nnor the whirring shuttle \xa0\xa0\xa0 move across me,\nnor the weaver\u2019s rods \xa0\xa0\xa0 anywhere smite me.',
#  u'worms do not weave me \xa0\xa0\xa0 with fatal wiles\nwhich fairly adorn \xa0\xa0\xa0 the fine yellow web.',
#  u'yet nevertheless \xa0\xa0\xa0 the wide world over\none will call me a joyful \xa0\xa0\xa0 garment for heroes.',
#  u'say now truly, \xa0\xa0\xa0 you cunning sage,\nlearned in language, \xa0\xa0\xa0 what this garment may be.',
#  u'i\u2018m a wonderful thing \xa0\xa0\xa0 shaped for fighting,\nbeautifully dressed, \xa0\xa0\xa0 dear to my master.',
#  u'gay colored is my byrnie; \xa0\xa0\xa0 bright wire that my wielder\nwho guides me gave me, \xa0\xa0\xa0 embraces the death-gem,\nwho sometimes to strife \xa0\xa0\xa0 directs my wanderings.',
#  u'then i bring home treasure \xa0\xa0\xa0 through the shining day,\nhandiwork of smiths, \xa0\xa0\xa0 gold to the dwellings.',
#  u'often i slay \xa0\xa0\xa0 living warriors\nwith weapons of war.',
#  u'a king adorns me\nwith jewels and silver \xa0\xa0\xa0 and honors me in the hall,\nnor withholds my praise, \xa0\xa0\xa0 publicly proclaims\nmy merits before men, \xa0\xa0\xa0 when they drink their mead;\nsometimes holds me back \xa0\xa0\xa0 or frees me when weary\nwith going into battle.',
#  u'i have often hurt another\nat the hands of his friend.',
#  u'i am far and wide hated,\naccursed among weapons.',
#  u'i must never hope\nthat a son will avenge me \xa0\xa0\xa0 on the life of my slayer\nif ever an enemy \xa0\xa0\xa0 assails me in battle;\nnor will my kin be increased, \xa0\xa0\xa0 the breed whence i sprang\u2014\nunless bereft of my lord \xa0\xa0\xa0 i might change to a new,\nturn from the owner \xa0\xa0\xa0 who first rewarded me.',
#  u'henceforth i am fated \xa0\xa0\xa0 if i follow a (new) lord\nto do battle for him \xa0\xa0\xa0 as i did for the other,\nfor my prince\u2019s pleasure, \xa0\xa0\xa0 that i must forego\nthe wealth of children \xa0\xa0\xa0 and know no woman;\nfor he who held me \xa0\xa0\xa0 of yore in thrall\ndenies me that bliss.',
#  u'i must therefore enjoy\nsingle, alone, \xa0\xa0\xa0 the wealth of heroes.',
#  u'often foolish in my finery \xa0\xa0\xa0 i enrage a woman,\ndiminish her desire; \xa0\xa0\xa0 her tongue abuses me;\nshe hits me with her hands, \xa0\xa0\xa0 reviles me with words,\nintones a curse.',
#  u'i like not this contest.\u2026',
#  u'i protect my hearth, \xa0\xa0\xa0 my hoard and my home,\nsurrounded by strands \xa0\xa0\xa0 and filled within\nwith excellent treasures.',
#  u'often by day\ni spit abroad \xa0\xa0\xa0 the terror of spears.',
#  u'my success is the greater \xa0\xa0\xa0 the more i am filled.',
#  u'my master sees this, \xa0\xa0\xa0 how darts fly from within me.',
#  u'sometimes i swallow \xa0\xa0\xa0 the swart dark weapons,\nthe poisoned darts.',
#  u'my entrails are good,\nprecious to warriors, \xa0\xa0\xa0 the hoard that i hold.',
#  u'many remember \xa0\xa0\xa0 what goes through my mouth.',
#  u'i was an armed fighter.',
#  u'now a young home-dweller\ncovers me proudly \xa0\xa0\xa0 with twisted wires,\nwith gold and silver.',
#  u'sometimes men kiss me.',
#  u'sometimes with my song \xa0\xa0\xa0 i summon to battle\nhappy comrades.',
#  u'sometimes a steed carries me\nover the marches.',
#  u'sometimes a sea-horse\nbears me over waves \xa0\xa0\xa0 with my bright trappings.',
#  u'sometimes a maiden \xa0\xa0\xa0 fills my ring-adorned bosom.',
#  u'sometimes i must lie \xa0\xa0\xa0 hard and headless\nstripped on the tables.',
#  u'sometimes i hang,\nwith ornaments proud, \xa0\xa0\xa0 on the wall where men drink.',
#  u'sometimes a good weapon, \xa0\xa0\xa0 the warriors bear me,\nriding on horseback, \xa0\xa0\xa0 with treasure laden,\ni must breathe in the breath \xa0\xa0\xa0 of a man\u2019s breast.',
#  u'sometimes with my music \xa0\xa0\xa0 i summon proud warriors\nto drink their wine.',
#  u'sometimes with my voice\ni rescue the booty, \xa0\xa0\xa0 put foe to flight.',
#  u'i am atheling\u2019s \xa0\xa0\xa0 shoulder-companion,\na warrior\u2019s comrade, \xa0\xa0\xa0 dear to my master,\na fellow of kings.',
#  u'his fair-haired lady\nsometimes will lay \xa0\xa0\xa0 her hand upon me,\na prince\u2019s daughter, \xa0\xa0\xa0 noble though she be.',
#  u'i have on my breast \xa0\xa0\xa0 what grew in the grove.',
#  u'sometimes i ride \xa0\xa0\xa0 on a proud steed\nat the army\u2019s head.',
#  u'hard is my tongue.',
#  u'often i bring \xa0\xa0\xa0 a reward for his words\nto the singer after his song.',
#  u'good is my note,\nand myself am dark-colored.',
#  u'say what my name is.',
#  u'i am an atheling\u2019s \xa0\xa0\xa0 possession and delight',
#  u'but i stood upright \xa0\xa0\xa0 where i [was],\ni and my brother.',
#  u'both of us were hard.',
#  u'the place was noble \xa0\xa0\xa0 where we two stood,\nthe higher in honor.',
#  u'the holt often hid us,\na shelter of trees \xa0\xa0\xa0 in the dark nights,\nshielded us from showers.',
#  u'the lord made us both.',
#  u'after us two large ones, \xa0\xa0\xa0 our kin will now follow us,\nyounger brothers \xa0\xa0\xa0 will drive us from our home.',
#  u'i am unique in the world.',
#  u'my back itself\nis dark and wonderful.',
#  u'i stand on the wood,\nat the end of the board.',
#  u'my brother is not here,\nbut brotherless now \xa0\xa0\xa0 i must keep my place\nat the end of the board \xa0\xa0\xa0 and firmly stand.',
#  u'i know not where \xa0\xa0\xa0 my brother is now\nor where he dwells \xa0\xa0\xa0 on the bosom of earth,\nwho formerly dwelt \xa0\xa0\xa0 high by my side.',
#  u'we stood together \xa0\xa0\xa0 in making war;\nneither alone \xa0\xa0\xa0 declared his strength,\nelse were we in battle \xa0\xa0\xa0 both unavailing.',
#  u'now strange beings \xa0\xa0\xa0 tear into me,\ninjure my insides.',
#  u'i cannot escape.',
#  u'on the tracks he will find \xa0\xa0\xa0 success, he who seeks it,\n.',
#  u'his soul\u2019s profit.',
#  u'old with many days \xa0\xa0\xa0 over deep streams;\nsometimes he would climb \xa0\xa0\xa0 the steep hills\nup in his homeland; \xa0\xa0\xa0 sometimes he went back\ninto deep dales, \xa0\xa0\xa0 seeking for safety,\nstrong of stride.',
#  u'he dug into stony ground,\nfrozen hard; \xa0\xa0\xa0 sometimes he shook the frost\nfrom his bright white hair.',
#  u'i rode with the eager ones\nuntil my younger brother \xa0\xa0\xa0 seized the seat of joy\nand drove me off \xa0\xa0\xa0 from my own home.',
#  u'then the dark iron \xa0\xa0\xa0 wounded me within;\nno blood flowed forth, \xa0\xa0\xa0 no gore from within\nthough the sharp-edged steel \xa0\xa0\xa0 bit into me hard.',
#  u'i mourned not the time, \xa0\xa0\xa0 nor wept for the wound,\nnor could i avenge \xa0\xa0\xa0 my heavy fate,\na life for a life: \xa0\xa0\xa0 but i suffer the torment\nof all that bit the shield.',
#  u'now i swallow the black,\nthe wood and water.',
#  u'i embrace within me\nwhat falls from above \xa0\xa0\xa0 on me where i stand\n(it is something dark).',
#  u'i have one foot.',
# ...
#  u'ask what my name is \xa0\xa0\xa0 who bind men to the ground,\nthe foolish after fighting, \xa0\xa0\xa0 in broad daylight.',
#  u'a thing came marvelously \xa0\xa0\xa0 moving over the waves,\ncomely from the keel up.',
#  u'it called out to the land,\nloudly resounding.',
#  u'its laughter was horrible,\nawful in its place.',
#  u'its edges were sharp;\nhateful it was, \xa0\xa0\xa0 and sluggish to battle,\nbitter in its hostile deeds.',
#  u'it dug into shield-walls,\nhard, ravaging.',
#  u'it spread mischievous spells.',
#  u'it spoke with cunning craft \xa0\xa0\xa0 about its creation:\n\u201cdearest of women \xa0\xa0\xa0 is indeed my mother;\nshe is my daughter \xa0\xa0\xa0 grown big and strong.',
#  u'it is known to men of old, \xa0\xa0\xa0 among all people,\nthat she shall stand up beautifully \xa0\xa0\xa0 everywhere in the world.\u201d',
#  u'there\u2019s a bit of earth \xa0\xa0\xa0 beautifully sown\nwith the hardest and the sharpest \xa0\xa0\xa0 and the grimmest that men own.',
#  u'cut and cleaned, \xa0\xa0\xa0 turned and dried;\npleached and wound; \xa0\xa0\xa0 bleached and bound;\nadorned and arrayed \xa0\xa0\xa0 and borne away\nto the doors of men.',
#  u'joy is within\nfor living creatures.',
#  u'it delays and it stays\na long long while.',
#  u'they live in joy\nand naught gainsays.',
#  u'but after the death\nthey start talking big, \xa0\xa0\xa0 chattering, chittering.',
#  u'it is hard for a wise man \xa0\xa0\xa0 to say what this is.',
#  u'a creature came \xa0\xa0\xa0 where many men\nsat at council \xa0\xa0\xa0 with wise hearts.',
#  u'it had one eye \xa0\xa0\xa0 and its ears were two;\nit had two feet \xa0\xa0\xa0 and twelve hundred heads,\na back and a belly \xa0\xa0\xa0 and two hands,\narms and shoulders, \xa0\xa0\xa0 one neck,\nand two sides.',
#  u'say what i\u2019m called.',
#  u'not silent is my hall, \xa0\xa0\xa0 nor i myself am loud\n.',
#  u'for us two the lord ordained\nour ways together.',
#  u'i am swifter than he\nand at times stronger; \xa0\xa0\xa0 he is more enduring.',
#  u'often i rest; \xa0\xa0\xa0 he must run on.',
#  u'with him is my home \xa0\xa0\xa0 all my life long.',
#  u'if we two are parted \xa0\xa0\xa0 my death is destined.',
#  u'came sixty riding on horseback to the seashore.',
#  u'eleven rode on stately steeds; four white horses.',
#  u'however they tried they could not cross the water,\nfor it was too deep and the banks too high and the currents too strong.',
#  u'so they climbed on a wagon, with their horses under the pole.',
#  u'then a horse bore them all, horses and proud men with spears,\nacross the bay and on to the land,\nthough no ox drew it, nor powerful slaves,\nnor stout steed\u2014neither swam nor walked\non the ground under the strange burden,\nnor stirred the waters, nor flew in the air, nor turned back.',
#  u'yet the men crossed the stream\nand their steeds also, from the high bank.',
#  u'so they strode up on the other side bravely,\nmen and horses, safe and sound from the water.',
#  u'he sat at his wine \xa0\xa0\xa0 with his two wives\nand his two sons \xa0\xa0\xa0 and his two daughters,\nthe beloved sisters, \xa0\xa0\xa0 and their two sons,\ngoodly first born.',
#  u'the father of each\nof these noble ones \xa0\xa0\xa0 was there and there also\nan uncle and a nephew.',
#  u'five in all,\nmen and women, \xa0\xa0\xa0 were sitting together.',
#  u'i saw two captives \xa0\xa0\xa0 carried in the house\nunder the hall-roof; \xa0\xa0\xa0 sturdy were they both;\ncompanions they were, \xa0\xa0\xa0 fast bound together.',
#  u'close to one of them \xa0\xa0\xa0 was a dark-skinned slave.',
#  u'she controlled them both \xa0\xa0\xa0 by fast fetters.',
#  u'i was a young woman, \xa0\xa0\xa0 a fair-haired lady,\nand at the same time \xa0\xa0\xa0 a peerless warrior;\ni flew with the birds \xa0\xa0\xa0 and swam in the sea,\ndove under the wave, \xa0\xa0\xa0 and was dead among fishes,\nand i walked on the ground.',
#  u'i had a living soul.',
#  u'i am a lordly, thing \xa0\xa0\xa0 known to nobles,\nand often i rest, \xa0\xa0\xa0 famous among peoples,\nthe mighty and the lowly; \xa0\xa0\xa0 i travel widely\nand to me first a stranger \xa0\xa0\xa0 remains to my friends\nthe delight of plunderers, \xa0\xa0\xa0 if i am to have\nsuccess in the cities \xa0\xa0\xa0 or bright reward.',
#  u'now wise men \xa0\xa0\xa0 exceedingly love\nmy presence.',
#  u'to many i shall\ndeclare wisdom.',
#  u'there they speak not,\nnone the world over.',
#  u'though now the sons of men\nwho live on the earth \xa0\xa0\xa0 eagerly seek\nthe tracks that i make.',
#  u'i sometimes conceal\nthose paths of mine \xa0\xa0\xa0 from all mankind.',
#  u'i\u2019m a wonderful thing; \xa0\xa0\xa0 i vary my voice:\ni bark like a dog, \xa0\xa0\xa0 i bleat like a goat,\ni quack like a goose, \xa0\xa0\xa0 i shriek like a hawk;\ni imitate the eagle, \xa0\xa0\xa0 the gray one, the cry\nof the fighting bird; \xa0\xa0\xa0 sometimes the kite\u2019s voice\nis familiar to my mouth, \xa0\xa0\xa0 or the sea-mew\u2019s song,\nwhere i happily sit.',
#  u'gift is my name,\noak and riding \xa0\xa0\xa0 and the god helps,hail and ice.',
#  u'now you have my name,\nas those six letters \xa0\xa0\xa0 clearly betoken.',
#  u'i saw there \xa0\xa0\xa0 two beautiful creatures\nopenly playing \xa0\xa0\xa0 the game of love.',
#  u'if the affair prospered, \xa0\xa0\xa0 the fair-haired one\nproudly arrayed, \xa0\xa0\xa0 received her due fulness.',
#  u'now i can tell \xa0\xa0\xa0 the assembled bookmen\nthe names of both \xa0\xa0\xa0 in runic letters.',
#  u'there shall be need, \xa0\xa0\xa0 two of these,\nand the bright ash tree, \xa0\xa0\xa0 one on the line,\nand then two oaks \xa0\xa0\xa0 and two hails likewise.',
#  u'whoever has unlocked \xa0\xa0\xa0 with the power of the key\nthe clasps of the chest \xa0\xa0\xa0 which held the riddle\ncunningly hidden \xa0\xa0\xa0 from the learned in runes\u2014\nnow is revealed to them \xa0\xa0\xa0 here as they drink\nhow those two of low minds \xa0\xa0\xa0 are called by name.',
#  u'i saw the wight \xa0\xa0\xa0 going on its way.',
#  u'it was splendidly, \xa0\xa0\xa0 wonderfully arrayed.',
#  u'the wonder was on the wave; \xa0\xa0\xa0 water became bone.',
#  u'i saw \u2026 \xa0\xa0\xa0 s r o\nh high-spirited, with gleaming head\nrinning swiftly \xa0\xa0\xa0 over the fair land;\nit had on its back \xa0\xa0\xa0 warlike strength.',
#  u'n o m \xa0\xa0\xa0 rode not-mailed\na g e w \xa0\xa0\xa0 far traveling it bore\nstrong on its way \xa0\xa0\xa0 a bold c o\nf o a h \xa0\xa0\xa0 the course was the brighter,\nthe journey of these.',
#  u'say what i am called.',
#  u'i saw w and i \xa0\xa0\xa0 going over the plain\nbearing b e. \xa0\xa0\xa0 for them both as they went\nwas the owner\u2019s joy; \xa0\xa0\xa0 h and a\nvery strong.',
#  u'th and e;\nthe f and a rejoiced; \xa0\xa0\xa0 flew over ea\ns and f \xa0\xa0\xa0 of the people themselves.',
#  u'i saw a thing \xa0\xa0\xa0 moving over the wave [or ways].',
#  u'it was gorgeously, \xa0\xa0\xa0 wondrously arrayed.',
#  u'it had four feet \xa0\xa0\xa0 beneath its belly[and eight man hwm \xa0\xa0\xa0 wiif mxlkfw\nf horse qxxs\u2014up on its back.]',
#  u'it had two wings \xa0\xa0\xa0 and twelve eyes\nand six heads.',
#  u'tell what it was.',
#  u'it moved over the water; \xa0\xa0\xa0 nor was it a bird alone,\nbut there was a likeness \xa0\xa0\xa0 of each of these:\na horse and a man, \xa0\xa0\xa0 a dog and a bird,\nand also the shape of a woman.',
#  u'you know\nhow to say, if you can, \xa0\xa0\xa0 who know the truth,\njust how the nature \xa0\xa0\xa0 of the thing may go.',
#  u'i saw a swift one \xa0\xa0\xa0 going along the path',
#  u'i\u2019m a wonderful thing, \xa0\xa0\xa0 a joy to women,\nto neighbors useful.',
#  u'i injure no one\nwho lives in a village \xa0\xa0\xa0 save only my slayer.',
#  u'i stand up high \xa0\xa0\xa0 and steep over the bed;\nunderneath i\u2019m shaggy.',
#  u'sometimes ventures\na young and handsome \xa0\xa0\xa0 peasant\u2019s daughter,\na maiden proud, \xa0\xa0\xa0 to lay hold on me.',
#  u'she seizes me, red, \xa0\xa0\xa0 plunders my head,\nfixes on me fast, \xa0\xa0\xa0 feels straightway\nwhat meeting me means \xa0\xa0\xa0 when she thus approaches,\na curly-haired woman.',
#  u'wet is that eye.',
#  u'splendidly it hangs \xa0\xa0\xa0 by a man\u2019s thigh,\nunder the master\u2019s cloak.',
#  u'in front is a hole.',
#  u'it is stiff and hard; \xa0\xa0\xa0 it has a goodly place.',
#  u'when the young man \xa0\xa0\xa0 his own garment\nlifts over his knee, \xa0\xa0\xa0 he wishes to visit\nwith the head of what hangs \xa0\xa0\xa0 the familiar hole\nhe had often filled \xa0\xa0\xa0 with its equal length.',
#  u'i have heard of something \xa0\xa0\xa0 wax in a corner,\nswell and pop, \xa0\xa0\xa0 lift up the covers.',
#  u'a proud-minded woman \xa0\xa0\xa0 seized with her hands\nthat boneless thing, \xa0\xa0\xa0 a prince\u2019s daughter;\ncovered with her dress \xa0\xa0\xa0 the swelling thing.',
#  u'a youth came along \xa0\xa0\xa0 to where he knew\nshe stood in a corner.',
#  u'forth he strode,\na vigorous young man, \xa0\xa0\xa0 lifted up her own\ndress with his hands, \xa0\xa0\xa0 thrust under her girdle\nsomething stiff \xa0\xa0\xa0 as she stood there;\nworked his will; \xa0\xa0\xa0 both of them shook.',
#  u'a thane hurried up, \xa0\xa0\xa0 useful at times,\na capable servant; \xa0\xa0\xa0 nonetheless he grew tired\nfrom time to time, \xa0\xa0\xa0 though strong at first,\nweary with work.',
#  u'beneath the girdle\nthere began to grow \xa0\xa0\xa0 what often good men\nlove heartily \xa0\xa0\xa0 and buy with money.',
#  u'often a goodly damsel, \xa0\xa0\xa0 a lady, locked me\nclose in a chest.',
#  u'sometimes with her hands\nshe took me out \xa0\xa0\xa0 and gave me to her lord,\na fine chieftain, \xa0\xa0\xa0 as he commanded her.',
#  u'then he thrust his head \xa0\xa0\xa0 well inside me,\nup from below, \xa0\xa0\xa0 into the narrow part.',
#  u'if the strength prevailed \xa0\xa0\xa0 of him who received me,\nadorned as i was, \xa0\xa0\xa0 something or other rough\nwas due to fill me.',
#  u'guess what i mean.',
#  u'i am hard and sharp, \xa0\xa0\xa0 strong in entering,\nbold in coming out, \xa0\xa0\xa0 good and true to my lord.',
#  u'i go in underneath \xa0\xa0\xa0 and myself open up\nthe proper way.',
#  u'the warrior is in haste\nwho pushes me from behind \xa0\xa0\xa0 a hero with his dress.',
#  u'sometimes he draws me out, \xa0\xa0\xa0 hot from the hole.',
#  u'sometimes i go back \xa0\xa0\xa0 in the narrow place\u2014\ni know not where.',
#  u'a southern man\ndrives me hard.',
#  u'say what my name is.',
#  u'a warrior is wondrously \xa0\xa0\xa0 brought into the world\nfor the use of lords \xa0\xa0\xa0 by two dumb things;\nbrightly extracted, \xa0\xa0\xa0 which for his hurt\nfoe bears against foe.',
#  u'strong though he is\na woman binds him.',
#  u'he obeys them well,\nserves them quietly, \xa0\xa0\xa0 if maids and men\ntend him duly, \xa0\xa0\xa0 feed him fairly.',
#  u'he exalts them in comfort \xa0\xa0\xa0 for their joy in life,\ngrimly rewards one \xa0\xa0\xa0 who lets him grow proud.',
#  u'i saw the thing; \xa0\xa0\xa0 its belly was at the back\nhugely puffed out.',
#  u'a servant attended it,\na man of might.',
#  u'and much had it suffered\nwhen that which filled it \xa0\xa0\xa0 flew from its eye.',
#  u'it does not always die \xa0\xa0\xa0 when it has to give\nwhat is in it to another.',
#  u'but there comes again\nreward to its bosom.',
#  u'its bloom returns.',
#  u'it creates a son; \xa0\xa0\xa0 it is its own father.',
#  u'i saw a marvelous thing; \xa0\xa0\xa0 it had a big belly\nmightily swollen.',
#  u'a servant followed it,\npowerful and strong of hand.',
#  u'great i thought him,\na goodly warrior.',
#  u'he seized hold at once,\nwith heaven\u2019s tooth \xa0\xa0\xa0 .',
#  u'blew in its eye.',
#  u'it barked,\nweakened willingly; \xa0\xa0\xa0 would none the less\n.',
#  u'i\u2019m a wonderful thing, \xa0\xa0\xa0 cannot say a word\nor speak for men \xa0\xa0\xa0 though i have a mouth\na broad belly \xa0\xa0\xa0 .',
#  u'i was on a ship \xa0\xa0\xa0 and more of my kindred.',
#  u'renewed\nthat is mother \xa0\xa0\xa0 of many kindreds,\nof the best, \xa0\xa0\xa0 of the darkest,\nof the dearest \xa0\xa0\xa0 that the children of men\nthroughout the bosom of earth \xa0\xa0\xa0 own with joy.',
#  u'we here on earth \xa0\xa0\xa0 cannot live at all\nunless we enjoy \xa0\xa0\xa0 what those children do.',
#  u'this is something for all mortals \xa0\xa0\xa0 to reflect on,\nall learned men, \xa0\xa0\xa0 what this thing is.',
#  u'often shall i prove \xa0\xa0\xa0 to be a thing of value\nto the joys of the hall \xa0\xa0\xa0 when i am brought forth,\nhappy with gold, \xa0\xa0\xa0 where men are drinking.',
#  u'often in the bower \xa0\xa0\xa0 the faithful servant\nkisses my mouth \xa0\xa0\xa0 where we two are together \u2026',
#  u'i have heard \xa0\xa0\xa0 of a splendid thing,\nof the lord of peoples, \xa0\xa0\xa0 a word of incantation \u2026\n\nseveral defective lines and then the conclusion:\n\n\n\n\n\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0i have become\na teacher of peoples, \xa0\xa0\xa0 live an eternal life\nin many lands, \xa0\xa0\xa0 while men inhabit\nthe bosom of earth.',
#  u'i have often seen it\nadorned with gold \xa0\xa0\xa0 where men were drinking,\nwith treasures and silver.',
#  u'say if you can,\nif you are wise enough, \xa0\xa0\xa0 what this thing is.',
#  u'i am a strong man\u2019s property \xa0\xa0\xa0 clothed in red [gold?].',
#  u'my place was first \xa0\xa0\xa0 the hard steep ground\nwith fair bright herbs.',
#  u'now i am the leavings of harsh things,\nthe fire and the file.',
#  u'i am closely constrained\nand honored with wires.',
#  u'he sometimes weeps,\nthe bearer of gold, \xa0\xa0\xa0 because of my grasp\nwhen i shall ravage \u2026',
#  u'ancient my lineage \xa0\xa0\xa0 .',
#  u'i lived in towns \xa0\xa0\xa0 after the keeper of fire\n.',
#  u'encircled with flame\npurified by fire.',
#  u'now earth\u2019s brother,\nan enemy, guards me, \xa0\xa0\xa0 who was first for me\na bringer of sorrow.',
#  u'full well i remember\nwho in the beginning \xa0\xa0\xa0 drove my lineage,\ndestroyed all the world.',
#  u'i may do him no harm,\nbut i raise up captivity \xa0\xa0\xa0 from time to time,\nthe wide world over.',
#  u'i have many glories,\nno little strength \xa0\xa0\xa0 in all the land,\nbut i must conceal \xa0\xa0\xa0 from every man\nthe secret power \xa0\xa0\xa0 of precious skill\nand the path i follow.',
#  u'tell what my name is.',
#  u'i was the boast of brown [things], \xa0\xa0\xa0 a tree in the forest,\na fine living thing \xa0\xa0\xa0 and a fruit of the field,\na foundation of joy, \xa0\xa0\xa0 a woman\u2019s message,\ngold in the homes.',
#  u'now i am a warrior\u2019s\nhappy weapon \xa0\xa0\xa0 with a ring \u2026',
#  u'smith \u2026\nhigher than heaven \u2026\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\u2026 than the sun\n.',
#  u'sharper than salt \u2026\ndearer than all this light, \xa0\xa0\xa0 brighter than \u2026',
#  u'it seemed strange to me, \xa0\xa0\xa0 a wolf held by a lamb;\nthe lamb fell \u2026 \xa0\xa0\xa0 and disemboweled the wolf.',
#  u'as i stood and watched \xa0\xa0\xa0 i beheld great glory:\nthere stood two wolves \xa0\xa0\xa0 troubling a third\u2014\nfour feet had they; \xa0\xa0\xa0 with seven eyes they saw.',
#  u'to my people it is as if one should give them a gift;\nthey will oppress him if he comes into the throng\nit is otherwise with us.',
#  u'wolf is on an island, i on another;\nthe island is firm, encompassed by marsh;\nthere are fierce men there on the island;\nthey will (etc.',
#  u'it is otherwise with us.',
#  u'for my wolf with far-wandering longings;\nthen it was rainy weather and i sat tearful,\nwhen the man bold in war surrounded me with boughs:\nit was joy for me so far, yet it was also pain.',
#  u'wolf, my wolf, thy hopes\nhave made me sick, thy rare visits\na grieving spirit, not at all want of food.',
#  u'dost thou hear, eadwacer?',
#  u'brisk cub of us two\nwolf bears to the wood.',
#  u'easily one tears asunder what was never united,\nour song together.']
